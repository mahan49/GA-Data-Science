# %%
import pandas as pd
import json

data = pd.read_csv("../../../lesson-13/code/dataset/stumbleupon.tsv", sep='\t')
data['title'] = data.boilerplate.map(lambda x: json.loads(x).get('title', ''))
data['body'] = data.boilerplate.map(lambda x: json.loads(x).get('body', ''))
data.head()
# Out:
#                                                  url  urlid  \
# 0  http://www.bloomberg.com/news/2010-12-23/ibm-p...   4042
# 1  http://www.popsci.com/technology/article/2012-...   8471
# 2  http://www.menshealth.com/health/flu-fighting-...   1164
# 3  http://www.dumblittleman.com/2007/12/10-foolpr...   6684
# 4  http://bleacherreport.com/articles/1205138-the...   9006
#
#                                          boilerplate alchemy_category  \
# 0  {"title":"IBM Sees Holographic Calls Air Breat...         business
# 1  {"title":"The Fully Electronic Futuristic Star...       recreation
# 2  {"title":"Fruits that Fight the Flu fruits tha...           health
# 3  {"title":"10 Foolproof Tips for Better Sleep "...           health
# 4  {"title":"The 50 Coolest Jerseys You Didn t Kn...           sports
#
#   alchemy_category_score  avglinksize  commonlinkratio_1  commonlinkratio_2  \
# 0               0.789131     2.055556           0.676471           0.205882
# 1               0.574147     3.677966           0.508021           0.288770
# 2               0.996526     2.382883           0.562016           0.321705
# 3               0.801248     1.543103           0.400000           0.100000
# 4               0.719157     2.676471           0.500000           0.222222
#
#    commonlinkratio_3  commonlinkratio_4  \
# 0           0.047059           0.023529
# 1           0.213904           0.144385
# 2           0.120155           0.042636
# 3           0.016667           0.000000
# 4           0.123457           0.043210
#
#                          ...                          linkwordscore  \
# 0                        ...                                     24
# 1                        ...                                     40
# 2                        ...                                     55
# 3                        ...                                     24
# 4                        ...                                     14
#
#    news_front_page  non_markup_alphanum_characters  numberOfLinks  \
# 0                0                            5424            170
# 1                0                            4973            187
# 2                0                            2240            258
# 3                0                            2737            120
# 4                0                           12032            162
#
#    numwords_in_url  parametrizedLinkRatio  spelling_errors_ratio label  \
# 0                8               0.152941               0.079130     0
# 1                9               0.181818               0.125448     1
# 2               11               0.166667               0.057613     1
# 3                5               0.041667               0.100858     1
# 4               10               0.098765               0.082569     0
#
#                                                title  \
# 0  IBM Sees Holographic Calls Air Breathing Batte...
# 1  The Fully Electronic Futuristic Starting Gun T...
# 2  Fruits that Fight the Flu fruits that fight th...
# 3                10 Foolproof Tips for Better Sleep
# 4  The 50 Coolest Jerseys You Didn t Know Existed...
#
#                                                 body
# 0  A sign stands outside the International Busine...
# 1  And that can be carried on a plane without the...
# 2  Apples The most popular source of antioxidants...
# 3  There was a period in my life when I had a lot...
# 4  Jersey sales is a curious business Whether you...
#
# [5 rows x 29 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

bodies = data['body'].dropna().copy()
vectorizer = CountVectorizer(max_features=1000, binary=False, stop_words='english')

# %%
X = vectorizer.fit_transform(bodies)#Does both fit and transform

# %%
id2word = dict(enumerate(vectorizer.get_feature_names()))

# %%
id2word # List of all of the data columns
# Out:
# {0: u'00',
#  1: u'000',
#  2: u'08',
#  3: u'09',
#  4: u'10',
#  5: u'100',
#  6: u'11',
#  7: u'12',
#  8: u'13',
#  9: u'14',
#  10: u'15',
#  11: u'16',
#  12: u'17',
#  13: u'18',
#  14: u'19',
#  15: u'20',
#  16: u'2005',
#  17: u'2006',
#  18: u'2007',
#  19: u'2008',
#  20: u'2009',
#  21: u'2010',
#  22: u'2011',
#  23: u'2012',
#  24: u'21',
#  25: u'22',
#  26: u'23',
#  27: u'24',
#  28: u'25',
#  29: u'26',
#  30: u'27',
#  31: u'28',
#  32: u'29',
#  33: u'30',
#  34: u'31',
#  35: u'35',
#  36: u'350',
#  37: u'40',
#  38: u'45',
#  39: u'50',
#  40: u'60',
#  41: u'ability',
#  42: u'able',
#  43: u'according',
#  44: u'actually',
#  45: u'ad',
#  46: u'add',
#  47: u'added',
#  48: u'adding',
#  49: u'addition',
#  50: u'additional',
#  51: u'age',
#  52: u'ago',
#  53: u'air',
#  54: u'alcohol',
#  55: u'allow',
#  56: u'amazing',
#  57: u'america',
#  58: u'american',
#  59: u'app',
#  60: u'apple',
#  61: u'apples',
#  62: u'april',
#  63: u'area',
#  64: u'aren',
#  65: u'art',
#  66: u'article',
#  67: u'aside',
#  68: u'ask',
#  69: u'asked',
#  70: u'athletes',
#  71: u'attention',
#  72: u'august',
#  73: u'author',
#  74: u'available',
#  75: u'average',
#  76: u'avocado',
#  77: u'avoid',
#  78: u'away',
#  79: u'awesome',
#  80: u'baby',
#  81: u'background',
#  82: u'bacon',
#  83: u'bad',
#  84: u'bag',
#  85: u'bake',
#  86: u'baked',
#  87: u'baking',
#  88: u'ball',
#  89: u'balls',
#  90: u'banana',
#  91: u'bar',
#  92: u'bars',
#  93: u'base',
#  94: u'based',
#  95: u'basic',
#  96: u'basil',
#  97: u'batter',
#  98: u'bean',
#  99: u'beans',
#  100: u'beat',
#  101: u'beautiful',
#  102: u'beauty',
#  103: u'beef',
#  104: u'beer',
#  105: u'begin',
#  106: u'believe',
#  107: u'benefits',
#  108: u'best',
#  109: u'better',
#  110: u'big',
#  111: u'bit',
#  112: u'black',
#  113: u'blend',
#  114: u'blog',
#  115: u'blood',
#  116: u'blue',
#  117: u'board',
#  118: u'body',
#  119: u'boil',
#  120: u'book',
#  121: u'bought',
#  122: u'bowl',
#  123: u'box',
#  124: u'brain',
#  125: u'bread',
#  126: u'break',
#  127: u'breakfast',
#  128: u'breast',
#  129: u'bring',
#  130: u'broccoli',
#  131: u'brown',
#  132: u'brownies',
#  133: u'business',
#  134: u'butter',
#  135: u'buy',
#  136: u'buzz',
#  137: u'cake',
#  138: u'cakes',
#  139: u'california',
#  140: u'called',
#  141: u'calories',
#  142: u'came',
#  143: u'campaign',
#  144: u'cancer',
#  145: u'candy',
#  146: u'car',
#  147: u'caramel',
#  148: u'care',
#  149: u'case',
#  150: u'category',
#  151: u'cause',
#  152: u'cells',
#  153: u'center',
#  154: u'certain',
#  155: u'chance',
#  156: u'change',
#  157: u'check',
#  158: u'cheddar',
#  159: u'cheese',
#  160: u'cheesecake',
#  161: u'chef',
#  162: u'chicken',
#  163: u'child',
#  164: u'children',
#  165: u'chili',
#  166: u'chinese',
#  167: u'chip',
#  168: u'chips',
#  169: u'chocolate',
#  170: u'choice',
#  171: u'cholesterol',
#  172: u'choose',
#  173: u'chopped',
#  174: u'christmas',
#  175: u'cinnamon',
#  176: u'city',
#  177: u'class',
#  178: u'classic',
#  179: u'clean',
#  180: u'clear',
#  181: u'click',
#  182: u'close',
#  183: u'clothing',
#  184: u'cloves',
#  185: u'coat',
#  186: u'cocoa',
#  187: u'coconut',
#  188: u'coffee',
#  189: u'cold',
#  190: u'collection',
#  191: u'college',
#  192: u'color',
#  193: u'com',
#  194: u'combination',
#  195: u'combine',
#  196: u'combined',
#  197: u'come',
#  198: u'comes',
#  199: u'coming',
#  200: u'comment',
#  201: u'comments',
#  202: u'common',
#  203: u'community',
#  204: u'company',
#  205: u'complete',
#  206: u'completely',
#  207: u'computer',
#  208: u'concept',
#  209: u'container',
#  210: u'content',
#  211: u'continue',
#  212: u'control',
#  213: u'cook',
#  214: u'cooked',
#  215: u'cookie',
#  216: u'cookies',
#  217: u'cooking',
#  218: u'cool',
#  219: u'corn',
#  220: u'cost',
#  221: u'couldn',
#  222: u'country',
#  223: u'couple',
#  224: u'course',
#  225: u'cover',
#  226: u'covered',
#  227: u'cream',
#  228: u'creamy',
#  229: u'create',
#  230: u'created',
#  231: u'crisp',
#  232: u'crumbs',
#  233: u'crust',
#  234: u'culture',
#  235: u'cup',
#  236: u'cupcake',
#  237: u'cupcakes',
#  238: u'cups',
#  239: u'cut',
#  240: u'daily',
#  241: u'damascus',
#  242: u'dark',
#  243: u'data',
#  244: u'date',
#  245: u'day',
#  246: u'days',
#  247: u'deal',
#  248: u'death',
#  249: u'december',
#  250: u'decided',
#  251: u'deep',
#  252: u'definitely',
#  253: u'degrees',
#  254: u'delicious',
#  255: u'design',
#  256: u'designed',
#  257: u'dessert',
#  258: u'desserts',
#  259: u'did',
#  260: u'didn',
#  261: u'diet',
#  262: u'different',
#  263: u'dinner',
#  264: u'dip',
#  265: u'directions',
#  266: u'disease',
#  267: u'dish',
#  268: u'dishes',
#  269: u'display',
#  270: u'div',
#  271: u'does',
#  272: u'doesn',
#  273: u'dog',
#  274: u'doing',
#  275: u'don',
#  276: u'double',
#  277: u'dough',
#  278: u'dr',
#  279: u'dress',
#  280: u'dried',
#  281: u'drink',
#  282: u'drinking',
#  283: u'drop',
#  284: u'drug',
#  285: u'dry',
#  286: u'early',
#  287: u'easier',
#  288: u'easily',
#  289: u'easy',
#  290: u'eat',
#  291: u'eating',
#  292: u'edges',
#  293: u'effect',
#  294: u'effects',
#  295: u'egg',
#  296: u'eggs',
#  297: u'electric',
#  298: u'email',
#  299: u'end',
#  300: u'energy',
#  301: u'enjoy',
#  302: u'entire',
#  303: u'especially',
#  304: u'evenly',
#  305: u'event',
#  306: u'exactly',
#  307: u'example',
#  308: u'exercise',
#  309: u'experience',
#  310: u'extra',
#  311: u'extract',
#  312: u'eye',
#  313: u'eyes',
#  314: u'face',
#  315: u'facebook',
#  316: u'fact',
#  317: u'fall',
#  318: u'false',
#  319: u'family',
#  320: u'fan',
#  321: u'fans',
#  322: u'far',
#  323: u'fashion',
#  324: u'fast',
#  325: u'fat',
#  326: u'favorite',
#  327: u'features',
#  328: u'february',
#  329: u'feel',
#  330: u'feeling',
#  331: u'feet',
#  332: u'fiber',
#  333: u'field',
#  334: u'filled',
#  335: u'filling',
#  336: u'finally',
#  337: u'fine',
#  338: u'firm',
#  339: u'fish',
#  340: u'fit',
#  341: u'fitness',
#  342: u'flashvars',
#  343: u'flat',
#  344: u'flavor',
#  345: u'flavors',
#  346: u'flour',
#  347: u'foil',
#  348: u'fold',
#  349: u'follow',
#  350: u'following',
#  351: u'food',
#  352: u'foods',
#  353: u'football',
#  354: u'form',
#  355: u'free',
#  356: u'freezer',
#  357: u'french',
#  358: u'fresh',
#  359: u'fridge',
#  360: u'fried',
#  361: u'friend',
#  362: u'friends',
#  363: u'frosting',
#  364: u'frozen',
#  365: u'fruit',
#  366: u'fruits',
#  367: u'fry',
#  368: u'fun',
#  369: u'function',
#  370: u'funny',
#  371: u'future',
#  372: u'game',
#  373: u'games',
#  374: u'garlic',
#  375: u'gently',
#  376: u'gets',
#  377: u'getting',
#  378: u'ginger',
#  379: u'girl',
#  380: u'given',
#  381: u'gives',
#  382: u'glass',
#  383: u'goes',
#  384: u'going',
#  385: u'gold',
#  386: u'golden',
#  387: u'good',
#  388: u'google',
#  389: u'got',
#  390: u'grated',
#  391: u'great',
#  392: u'green',
#  393: u'grill',
#  394: u'grilled',
#  395: u'ground',
#  396: u'group',
#  397: u'guide',
#  398: u'guy',
#  399: u'hair',
#  400: u'half',
#  401: u'hand',
#  402: u'hands',
#  403: u'happy',
#  404: u'hard',
#  405: u'having',
#  406: u'head',
#  407: u'health',
#  408: u'healthy',
#  409: u'heart',
#  410: u'heat',
#  411: u'heavy',
#  412: u'height',
#  413: u'help',
#  414: u'helps',
#  415: u'herbs',
#  416: u'high',
#  417: u'history',
#  418: u'hit',
#  419: u'hold',
#  420: u'holiday',
#  421: u'home',
#  422: u'homemade',
#  423: u'honey',
#  424: u'hope',
#  425: u'hot',
#  426: u'hour',
#  427: u'hours',
#  428: u'house',
#  429: u'href',
#  430: u'http',
#  431: u'huge',
#  432: u'human',
#  433: u'ice',
#  434: u'idea',
#  435: u'ideas',
#  436: u'image',
#  437: u'images',
#  438: u'immediately',
#  439: u'important',
#  440: u'improve',
#  441: u'inch',
#  442: u'inches',
#  443: u'include',
#  444: u'including',
#  445: u'increase',
#  446: u'industry',
#  447: u'information',
#  448: u'ingredients',
#  449: u'inside',
#  450: u'inspired',
#  451: u'instead',
#  452: u'instructions',
#  453: u'interesting',
#  454: u'international',
#  455: u'internet',
#  456: u'iphone',
#  457: u'isn',
#  458: u'issue',
#  459: u'italian',
#  460: u'items',
#  461: u'january',
#  462: u'job',
#  463: u'jpg',
#  464: u'juice',
#  465: u'july',
#  466: u'june',
#  467: u'just',
#  468: u'key',
#  469: u'kids',
#  470: u'kind',
#  471: u'kitchen',
#  472: u'knew',
#  473: u'knife',
#  474: u'know',
#  475: u'known',
#  476: u'la',
#  477: u'large',
#  478: u'later',
#  479: u'latest',
#  480: u'layer',
#  481: u'lead',
#  482: u'learn',
#  483: u'leave',
#  484: u'leaves',
#  485: u'left',
#  486: u'lemon',
#  487: u'let',
#  488: u'level',
#  489: u'levels',
#  490: u'life',
#  491: u'light',
#  492: u'lightly',
#  493: u'like',
#  494: u'likely',
#  495: u'lime',
#  496: u'line',
#  497: u'link',
#  498: u'liquid',
#  499: u'list',
#  500: u'little',
#  501: u'live',
#  502: u'living',
#  503: u'll',
#  504: u'local',
#  505: u'london',
#  506: u'long',
#  507: u'longer',
#  508: u'look',
#  509: u'looking',
#  510: u'looks',
#  511: u'lose',
#  512: u'loss',
#  513: u'lost',
#  514: u'lot',
#  515: u'lots',
#  516: u'love',
#  517: u'low',
#  518: u'lower',
#  519: u'lunch',
#  520: u'magazine',
#  521: u'main',
#  522: u'major',
#  523: u'make',
#  524: u'makes',
#  525: u'making',
#  526: u'man',
#  527: u'march',
#  528: u'market',
#  529: u'matter',
#  530: u'maybe',
#  531: u'meal',
#  532: u'meals',
#  533: u'mean',
#  534: u'means',
#  535: u'meat',
#  536: u'media',
#  537: u'medical',
#  538: u'medicine',
#  539: u'medium',
#  540: u'melt',
#  541: u'melted',
#  542: u'memory',
#  543: u'men',
#  544: u'method',
#  545: u'microwave',
#  546: u'middle',
#  547: u'milk',
#  548: u'million',
#  549: u'mind',
#  550: u'mini',
#  551: u'minute',
#  552: u'minutes',
#  553: u'mix',
#  554: u'mixed',
#  555: u'mixer',
#  556: u'mixing',
#  557: u'mixture',
#  558: u'model',
#  559: u'models',
#  560: u'mom',
#  561: u'moment',
#  562: u'money',
#  563: u'month',
#  564: u'months',
#  565: u'morning',
#  566: u'mother',
#  567: u'muffin',
#  568: u'muscle',
#  569: u'muscles',
#  570: u'mushrooms',
#  571: u'music',
#  572: u'national',
#  573: u'natural',
#  574: u'need',
#  575: u'needed',
#  576: u'needs',
#  577: u'network',
#  578: u'new',
#  579: u'news',
#  580: u'nfl',
#  581: u'nice',
#  582: u'night',
#  583: u'non',
#  584: u'normal',
#  585: u'note',
#  586: u'november',
#  587: u'number',
#  588: u'nutella',
#  589: u'nutrition',
#  590: u'nuts',
#  591: u'october',
#  592: u'offer',
#  593: u'offers',
#  594: u'office',
#  595: u'oh',
#  596: u'oil',
#  597: u'old',
#  598: u'olive',
#  599: u'olympic',
#  600: u'olympics',
#  601: u'ones',
#  602: u'onion',
#  603: u'onions',
#  604: u'online',
#  605: u'open',
#  606: u'optional',
#  607: u'orange',
#  608: u'order',
#  609: u'organic',
#  610: u'original',
#  611: u'ounces',
#  612: u'outside',
#  613: u'oven',
#  614: u'oz',
#  615: u'package',
#  616: u'page',
#  617: u'pain',
#  618: u'pan',
#  619: u'paper',
#  620: u'parchment',
#  621: u'parents',
#  622: u'parmesan',
#  623: u'party',
#  624: u'past',
#  625: u'pasta',
#  626: u'pastry',
#  627: u'peanut',
#  628: u'people',
#  629: u'pepper',
#  630: u'peppers',
#  631: u'percent',
#  632: u'perfect',
#  633: u'person',
#  634: u'personal',
#  635: u'phone',
#  636: u'photo',
#  637: u'photography',
#  638: u'photos',
#  639: u'physical',
#  640: u'pick',
#  641: u'picture',
#  642: u'pictures',
#  643: u'pie',
#  644: u'piece',
#  645: u'pieces',
#  646: u'pink',
#  647: u'pizza',
#  648: u'place',
#  649: u'plan',
#  650: u'plastic',
#  651: u'plate',
#  652: u'play',
#  653: u'player',
#  654: u'plus',
#  655: u'pm',
#  656: u'point',
#  657: u'police',
#  658: u'pop',
#  659: u'popular',
#  660: u'pork',
#  661: u'position',
#  662: u'possible',
#  663: u'post',
#  664: u'posted',
#  665: u'posts',
#  666: u'pot',
#  667: u'potato',
#  668: u'potatoes',
#  669: u'pound',
#  670: u'pounds',
#  671: u'pour',
#  672: u'powder',
#  673: u'powdered',
#  674: u'power',
#  675: u'preheat',
#  676: u'prepare',
#  677: u'prepared',
#  678: u'press',
#  679: u'pressure',
#  680: u'pretty',
#  681: u'prevent',
#  682: u'print',
#  683: u'probably',
#  684: u'problem',
#  685: u'problems',
#  686: u'process',
#  687: u'processor',
#  688: u'produce',
#  689: u'product',
#  690: u'products',
#  691: u'program',
#  692: u'project',
#  693: u'protein',
#  694: u'provide',
#  695: u'public',
#  696: u'published',
#  697: u'pull',
#  698: u'pumpkin',
#  699: u'purpose',
#  700: u'quality',
#  701: u'question',
#  702: u'quick',
#  703: u'quickly',
#  704: u'quite',
#  705: u'rack',
#  706: u'raw',
#  707: u'read',
#  708: u'reading',
#  709: u'ready',
#  710: u'real',
#  711: u'really',
#  712: u'reason',
#  713: u'recent',
#  714: u'recently',
#  715: u'recipe',
#  716: u'recipes',
#  717: u'red',
#  718: u'reduce',
#  719: u'refrigerator',
#  720: u'regular',
#  721: u'related',
#  722: u'remaining',
#  723: u'remember',
#  724: u'remove',
#  725: u'repeat',
#  726: u'report',
#  727: u'research',
#  728: u'researchers',
#  729: u'rest',
#  730: u'restaurant',
#  731: u'result',
#  732: u'results',
#  733: u'return',
#  734: u'review',
#  735: u'rice',
#  736: u'rich',
#  737: u'right',
#  738: u'rise',
#  739: u'risk',
#  740: u'roasted',
#  741: u'roll',
#  742: u'rolls',
#  743: u'room',
#  744: u'round',
#  745: u'run',
#  746: u'running',
#  747: u'safe',
#  748: u'said',
#  749: u'salad',
#  750: u'salt',
#  751: u'san',
#  752: u'sandwich',
#  753: u'sauce',
#  754: u'saucepan',
#  755: u'save',
#  756: u'saw',
#  757: u'say',
#  758: u'says',
#  759: u'school',
#  760: u'science',
#  761: u'search',
#  762: u'season',
#  763: u'second',
#  764: u'seconds',
#  765: u'seeds',
#  766: u'seen',
#  767: u'self',
#  768: u'september',
#  769: u'serve',
#  770: u'served',
#  771: u'serving',
#  772: u'set',
#  773: u'sex',
#  774: u'shape',
#  775: u'share',
#  776: u'sheet',
#  777: u'shoes',
#  778: u'shop',
#  779: u'short',
#  780: u'shows',
#  781: u'shredded',
#  782: u'shrimp',
#  783: u'si',
#  784: u'sides',
#  785: u'sign',
#  786: u'similar',
#  787: u'simmer',
#  788: u'simple',
#  789: u'simply',
#  790: u'single',
#  791: u'sit',
#  792: u'site',
#  793: u'size',
#  794: u'skillet',
#  795: u'skin',
#  796: u'sleep',
#  797: u'slice',
#  798: u'sliced',
#  799: u'slices',
#  800: u'slightly',
#  801: u'slow',
#  802: u'slowly',
#  803: u'small',
#  804: u'smooth',
#  805: u'snack',
#  806: u'social',
#  807: u'soda',
#  808: u'soft',
#  809: u'soon',
#  810: u'soup',
#  811: u'sour',
#  812: u'source',
#  813: u'space',
#  814: u'special',
#  815: u'speed',
#  816: u'spend',
#  817: u'spice',
#  818: u'spinach',
#  819: u'spoon',
#  820: u'sport',
#  821: u'sports',
#  822: u'spray',
#  823: u'spread',
#  824: u'spring',
#  825: u'sprinkle',
#  826: u'stand',
#  827: u'star',
#  828: u'start',
#  829: u'started',
#  830: u'starting',
#  831: u'state',
#  832: u'states',
#  833: u'static',
#  834: u'stay',
#  835: u'steak',
#  836: u'step',
#  837: u'stick',
#  838: u'stir',
#  839: u'stirring',
#  840: u'stop',
#  841: u'store',
#  842: u'story',
#  843: u'straight',
#  844: u'strawberries',
#  845: u'strawberry',
#  846: u'street',
#  847: u'stress',
#  848: u'strong',
#  849: u'studies',
#  850: u'study',
#  851: u'stuff',
#  852: u'style',
#  853: u'sugar',
#  854: u'summer',
#  855: u'sun',
#  856: u'super',
#  857: u'support',
#  858: u'sure',
#  859: u'surface',
#  860: u'sweet',
#  861: u'swimsuit',
#  862: u'syrup',
#  863: u'table',
#  864: u'tablespoon',
#  865: u'tablespoons',
#  866: u'taken',
#  867: u'takes',
#  868: u'taking',
#  869: u'talk',
#  870: u'taste',
#  871: u'tasty',
#  872: u'tbsp',
#  873: u'tea',
#  874: u'team',
#  875: u'teaspoon',
#  876: u'teaspoons',
#  877: u'tech',
#  878: u'technology',
#  879: u'tell',
#  880: u'temperature',
#  881: u'tender',
#  882: u'term',
#  883: u'terminal01',
#  884: u'test',
#  885: u'text',
#  886: u'texture',
#  887: u'thank',
#  888: u'thanks',
#  889: u'thing',
#  890: u'things',
#  891: u'think',
#  892: u'thinking',
#  893: u'thought',
#  894: u'throw',
#  895: u'time',
#  896: u'times',
#  897: u'tip',
#  898: u'tips',
#  899: u'today',
#  900: u'told',
#  901: u'tomato',
#  902: u'tomatoes',
#  903: u'took',
#  904: u'topping',
#  905: u'toss',
#  906: u'total',
#  907: u'touch',
#  908: u'track',
#  909: u'traditional',
#  910: u'training',
#  911: u'transfer',
#  912: u'treat',
#  913: u'treatment',
#  914: u'tried',
#  915: u'true',
#  916: u'try',
#  917: u'trying',
#  918: u'tsp',
#  919: u'turkey',
#  920: u'turn',
#  921: u'turned',
#  922: u'tv',
#  923: u'twitter',
#  924: u'type',
#  925: u'types',
#  926: u'united',
#  927: u'university',
#  928: u'unsalted',
#  929: u'url',
#  930: u'use',
#  931: u'used',
#  932: u'user',
#  933: u'username',
#  934: u'users',
#  935: u'uses',
#  936: u'using',
#  937: u'usually',
#  938: u'vanilla',
#  939: u'var',
#  940: u'variety',
#  941: u've',
#  942: u'vegan',
#  943: u'vegetable',
#  944: u'vegetables',
#  945: u'vegetarian',
#  946: u'version',
#  947: u'video',
#  948: u'videos',
#  949: u'view',
#  950: u'vinegar',
#  951: u'vitamin',
#  952: u'wait',
#  953: u'want',
#  954: u'wanted',
#  955: u'warm',
#  956: u'wasn',
#  957: u'watch',
#  958: u'water',
#  959: u'way',
#  960: u'ways',
#  961: u'wear',
#  962: u'web',
#  963: u'website',
#  964: u'week',
#  965: u'weeks',
#  966: u'weight',
#  967: u'went',
#  968: u'wheat',
#  969: u'whipped',
#  970: u'whisk',
#  971: u'white',
#  972: u'whites',
#  973: u'wide',
#  974: u'width',
#  975: u'win',
#  976: u'wine',
#  977: u'winter',
#  978: u'woman',
#  979: u'women',
#  980: u'won',
#  981: u'wonderful',
#  982: u'words',
#  983: u'work',
#  984: u'working',
#  985: u'workout',
#  986: u'works',
#  987: u'world',
#  988: u'worth',
#  989: u'wrap',
#  990: u'wrong',
#  991: u'www',
#  992: u'year',
#  993: u'years',
#  994: u'yeast',
#  995: u'yellow',
#  996: u'yes',
#  997: u'yogurt',
#  998: u'york',
#  999: u'young'}

# %%
from gensim.models.ldamodel import LdaModel
from gensim.matutils import Sparse2Corpus
# First we convert our word-matrix into gensim's format
corpus = Sparse2Corpus(X, documents_columns = False)
# Then we fit an LDA model
lda_model = LdaModel(corpus=corpus, id2word=id2word, num_topics=15)
# Out:
# C:\Users\mahan.hadjizadeh\AppData\Local\Continuum\anaconda2\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
num_topics = 5 #Change this number to get a number of meaningful topics
num_words_per_topic = 10
for ti, topic in enumerate(lda_model.show_topics(num_topics = num_topics, num_words = num_words_per_topic)):
    print("Topic: %d" % (ti))
    print (topic)
    print()
# Out:
# Topic: 0
# (10, u'0.025*"cup" + 0.020*"butter" + 0.016*"minutes" + 0.015*"sugar" + 0.013*"add" + 0.012*"baking" + 0.011*"recipe" + 0.010*"chocolate" + 0.010*"flour" + 0.010*"dough"')
# ()
# Topic: 1
# (2, u'0.025*"iphone" + 0.025*"app" + 0.015*"food" + 0.014*"box" + 0.011*"like" + 0.010*"free" + 0.010*"make" + 0.009*"ad" + 0.008*"com" + 0.008*"funny"')
# ()
# Topic: 2
# (12, u'0.026*"juice" + 0.025*"lemon" + 0.022*"sleep" + 0.018*"fruit" + 0.013*"sugar" + 0.011*"cup" + 0.011*"00" + 0.010*"pizza" + 0.010*"orange" + 0.009*"dress"')
# ()
# Topic: 3
# (13, u'0.015*"food" + 0.014*"cheese" + 0.012*"recipe" + 0.011*"make" + 0.010*"chicken" + 0.009*"sauce" + 0.009*"cook" + 0.009*"add" + 0.009*"just" + 0.008*"bread"')
# ()
# Topic: 4
# (4, u'0.017*"health" + 0.015*"body" + 0.011*"foods" + 0.011*"help" + 0.010*"people" + 0.010*"food" + 0.010*"like" + 0.010*"weight" + 0.009*"time" + 0.009*"fat"')
# ()

# %%
from gensim.models.word2vec import Word2Vec
# Setup the body text
text = data.body.dropna().map(lambda x: x.split())
model = Word2Vec(text, size=100, window=5, min_count=5, workers=4)

# %%
model.most_similar(positive=['cookie', 'brownie'])
# Out:
# [(u'cupcake', 0.9373154640197754),
#  (u'pie', 0.8372806310653687),
#  (u'cake', 0.8356108665466309),
#  (u'mini', 0.8338462114334106),
#  (u'candy', 0.8148970603942871),
#  (u'pancake', 0.8107501864433289),
#  (u'cakes', 0.8056097626686096),
#  (u'pudding', 0.8052595853805542),
#  (u'icing', 0.8037812113761902),
#  (u'cheesecake', 0.8036814332008362)]

# %%
# Unicode Handling
from __future__ import unicode_literals
import codecs

import numpy as np
import gensim

# spacy is used for pre-processing and traditional NLP
import spacy
from spacy.en import English

# Gensim is used for LDA and word2vec
from gensim.models.word2vec import Word2Vec

# %%
# Loading the tweet data
filename = '../dataset/captured-tweets.txt'
tweets = []
for tweet in codecs.open(filename, 'r', encoding="utf-8"):
    tweets.append(tweet)
# Setting up spacy
nlp_toolkit = English()

# %%
tweet_df = pd.DataFrame({'tweet':tweets})
tweet_df.head()
# Out:
#                                                tweet
# 0  I made a(n) Small Tourmaline in Paradise Islan...
# 1  RT @PURELOVEBEAST: -เช็ครายละเอียด- 27th BIRTH...
# 2                          https://t.co/EOfBdVQUfO\n
# 3                      @ViGiGu google it :) simple\n
# 4           nerd ass girl  https://t.co/T7kDirxPEL\n

# %% [markdown]
# ## Exercise 1a
#
# Write a function that can take a take a sentence parsed by `spacy` and identify if it mentions a company named 'Google'. Remember, `spacy` can find entities and codes them as `ORG` if they are a company. Look at the slides for class 13 if you need a hint:
#
# ### Bonus (1b)
#
# Parameterize the company name so that the function works for any company.

# %%
def mentions_company(parsed):
    parsed = nlp_toolkit(parsed)
    # Return True if the sentence contains an organization and that organization is Google
#     if(any([word.ent_type_ == 'ORG' for word in parsed])):
    if any([str(word)=='Google' for word in parsed]):
            return True
    return False
# 1b
def mentions_company(parsed, company='Google'):
#     Your code here
    parsed = nlp_toolkit(parsed)
    if any([str(word)==company for word in parsed]):
            return True
    return False

print tweet_df[tweet_df.tweet.map(lambda x: mentions_company(x, 'Google'))]
# Out:
# C:\Users\mahan.hadjizadeh\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:12: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if sys.path[0] == '':
#                                                   tweet
# 8                          Google Play Gift Card Code\n
# 9     Claim your Google Play Gift Card Code... https...
# 13    King of dark fantasy. Summon today. App Store:...
# 14    King of dark fantasy. Summon today. App Store:...
# 16    I've entered to win a Google Nexus 6P from  ! ...
# 18    RT @kamcb29: I've entered to win a Google Nexu...
# 20    I LOVE your Google plus page with the other gi...
# 21    After I've Google &amp; read a ton of articles...
# 23    RT @ShowerThoughtts: Apple has "air", Amazon h...
# 24    -Looks up on Google 'MikexJeremy' secretly- &l...
# 25    RT @_silentbent_: Go support @dadeputy single ...
# 29    Ever wanted to become a Google Small Business ...
# 31    Top Android Apps (without all the games) revea...
# 33    https://t.co/0ElEQm917Q How To Increase Blog T...
# 35                        Europe could produce a Fac...
# 38                        Europe could produce a Fac...
# 40    New post: Google Knowledge Graph Optimization ...
# 41    Anyone else spend the entire time driving tryi...
# 43    Google, you've failed me for the first time! W...
# 48                                    Google #Team2PM\n
# 53    RT https://t.co/s2HOfLUV2t #Google '#Android N...
# 57    @ImbruedJoint Hector had softly tilted his hea...
# 60    Google Knowledge Graph Optimization Strategies...
# 61    LebanonHashtag: RT probrandz: #Facebook Open S...
# 63    @r0thejan Earn free Google Play and many more ...
# 64    KalGuntuku: RT bunnymiilk "RT 30seclovelive: [...
# 65    RT @FortuneMagazine: Here’s how Google is taki...
# 67    shenbrood: What's your greatest #digitalmarket...
# 68    https://t.co/tkiiygFXRd What each state #Googl...
# 70    Europe could produce a Facebook - and the Goog...
# ...                                                 ...
# 3182  RT @Allanimeinforma: Top 10 searched keywords ...
# 3186  RT @Scribessy: Tips to Improve Your Business w...
# 3188  Google got its name by accident. The founders ...
# 3190  11 Google tricks that will change the way you ...
# 3191  RT @mindglobal: Like it or not, v wil get more...
# 3193  RT @RetiredFilth: Gotta set a Google calendar ...
# 3195  Come join me in an epic adventure. Invite ID: ...
# 3198  King of dark fantasy. Summon today. App Store:...
# 3199  King of dark fantasy. Summon today. App Store:...
# 3203  RT @mindglobal: Like it or not, v wil get more...
# 3204  King of dark fantasy. Summon today. App Store:...
# 3205  RT @Nickelodeon_AU: Download our app #NickPlay...
# 3206  @twitersgoodboy @IceBergMama Google emoji are ...
# 3207  Google Dorks SQLi Colleciton - https://t.co/1k...
# 3208     RT @GoogleInvestor: Google Up +1.6% for Week\n
# 3212  New Google Chat App Could Destroy Facebook Mes...
# 3213  Amateur Archaeologist + Google Earth = Bronze ...
# 3214  I added a video to a @YouTube playlist https:/...
# 3216  King of dark fantasy. Summon today. App Store:...
# 3217  RT @ramprasad_c: .@sardesairajdeep It takes 58...
# 3219  King of dark fantasy. Summon today. App Store:...
# 3220  RT @GoogleInvestor: Google Up +$247.35 &amp; +...
# 3222  King of dark fantasy. Summon today. App Store:...
# 3223  King of dark fantasy. Summon today. App Store:...
# 3226  New Event Now On. Get New Rank S Monsters. App...
# 3228  Top Android Apps (without all the games) revea...
# 3230  RT @TechnoBuffalo: Nexus owners report sync is...
# 3979  #Google Taking Aim at Uber in 2016 https://t.c...
# 4807  Microsoft joins Google and Facebook with warni...
# 4898  Predictions 2016: Apple, Tesla, Google, Medium...
#
# [1353 rows x 1 columns]

# %% [markdown]
# ## Exercise 1c
#
# Write a function that can take a sentence parsed by `spacy`
# and return the verbs of the sentence (preferably lemmatized)

# %%
def get_actions(parsed):
    actions = []
    # Your code here
    return actions

# %% [markdown]
# ## Exercise 1d
# For each tweet, parse it using spacy and print it out if the tweet has 'release' or 'announce' as a verb. You'll need to use your `mentions_company` and `get_actions` functions.

# %%
for tweet in tweets:
    parsed = nlp_toolkit(tweet)
    if any([str(word)=='Google' for word in parsed]):
        if any([((word.lemma_ == 'release') or (word.lemma_ == 'announce')) for word in parsed]):
            print tweet, "\n"
# Out:
# C:\Users\mahan.hadjizadeh\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:3: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   This is separate from the ipykernel package so we can avoid doing imports until
# Google &amp; Ford rumored to announce partnership at CES https://t.co/zOgm1NjHhD https://t.co/Gzx81ujqVC
#
#
# Lenovo And Google To Officially Announce Project Tango On January 7 At CES https://t.co/Qvmc34T5QA
#
#
# Lenovo And Google To Officially Announce Project Tango On January 7 At CES https://t.co/GNmL0uw9xl
#
#
# Google's Project Ara Spiral is expected to be released next year January https://t.co/prycPMuGsG
#
#
# #Lenovo And #Google To Officially Announce #ProjectTango On January 7 At CES https://t.co/04seCBKv16
#
#
# RT @GizmoChina: Lenovo And Google To Officially Announce Project Tango On January 7 At CES https://t.co/GNmL0uw9xl
#
#
# Google and Ford to announce partnership on self-driving cars at CES - Fudzilla (blog) https://t.co/6woe56G22Q
#
#
# Google and Ford to announce partnership on self-driving cars at CES - Fudzilla (blog) https://t.co/4hERVJ4zZK
#
#
# Redesigned Google Glass published on FCC website: release date, Price and features - Tampa Bay Review https://t.co/Vdwr4afx3E www.GlassRoo…

# %% [markdown]
# ## Exercise 1e
# Write a function that identifies countries - HINT: the entity label for countries is GPE (or GeoPolitical Entity)

# %%
def mentions_country(parsed, country):
    pass

# %% [markdown]
# ## Exercise 1f
#
# Re-run (d) to find country tweets that discuss 'Iran' announcing or releasing.

# %%
for tweet in tweets:
    parsed = nlp_toolkit(tweet)
    if any([str(word)=='Iran' for word in parsed]):
        if any([((word.lemma_ == 'release') or (word.lemma_ == 'announce')) for word in parsed]):
            print tweet, "\n" #"\n" adds a new line
# Out:
# C:\Users\mahan.hadjizadeh\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:3: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   This is separate from the ipykernel package so we can avoid doing imports until
# RT @nazirumikailu: Iran pressures Nigeria, demands the release of top Shia leader Ibrahim El-Zakzaky https://t.co/z5vVXQyxLN #BBCAfricaLive
#
#
# RT @cerenomri: "Literally every US ally in Mideast is on brink of hot war w/ Iran, so we're going to release $100 billion to Iran this mont…
#
#
# GOBE! Iran warns Nigeria to release Shiite leader El-Zakzaky - SEE https://t.co/TRshnC6sVU
#
#
# GOBE! Iran warns Nigeria to release Shiite leader El-Zakzaky - SEE https://t.co/SlvcQtk3vE
#
#
# RT @Vatescorp: #Sudan: Ministry of Foreign Affairs announced Khartoum has decided to sever diplomatic ties with #Iran https://t.co/ofQG8gtL…
#
#
# RT @cerenomri: "Literally every US ally in Mideast is on brink of hot war w/ Iran, so we're going to release $100 billion to Iran this mont…
#
#
# Hhmmm. Iran claiming to have 'warned Nigeria' to release detained Shiite leader.... @afalli
#
#
# RT @KenGardner11: Arab allies are breaking diplomatic relations with Iran. Obama's response? Release $100 billion to Iran. The quintessenti…
#
#
# RT @cerenomri: "Literally every US ally in Mideast is on brink of hot war w/ Iran, so we're going to release $100 billion to Iran this mont…
#
#
# RT @NEWS957: Saudi Arabia announces it is severing ties with Iran, Canada urging diplomacy https://t.co/7JE6dOHoQV
#
#
# Saudi Arabia Just Announced It Plans On Severing Ties With Iran after a Tumultuous Weekend https://t.co/ERj1bScAn5 via @ijdotcom
#
#
# RT @ahmed: Full transcript of press conference where Saudi FM @AdelAljubeir announced cutting diplomatic relations with Iran https://t.co/L…
#
#
# RT @Ebuka_Mbanefo: We have warned Nigeria to release ZakZaky - Islamic Republic Of Iran - https://t.co/7oBA1G4sYH

# %% [markdown]
# ## Exercise 2
# Build a `word2vec` model of the tweets we have collected using `gensim`.
#
# ### Exercise 2a:
# First take the collection of tweets and tokenize them using spacy.
#
# * Think about how this should be done.
# * Should you only use upper-case or lower-case?
# * Should you remove punctuations or symbols?

# %%
text_split = [[x.text if x.pos != spacy.parts_of_speech.VERB else x.lemma_ 
                for x in nlp_toolkit(t)] for t in tweets]
text_split
# Out:
# [[u'I',
#   u'make',
#   u'a(n',
#   u')',
#   u'Small',
#   u'Tourmaline',
#   u'in',
#   u'Paradise',
#   u'Island',
#   u'!',
#   u'https://t.co/cAoW1b6DRc',
#   u'#',
#   u'Gameinsight',
#   u'#',
#   u'Androidgames',
#   u'#',
#   u'Android',
#   u'\n'],
#  [u'RT',
#   u'@PURELOVEBEAST',
#   u':',
#   u'-\u0e40\u0e0a\u0e47\u0e04\u0e23\u0e32\u0e22\u0e25\u0e30\u0e40\u0e2d\u0e35\u0e22\u0e14-',
#   u'27th',
#   u'BIRTHDAY',
#   u'SPECIAL',
#   u'GOODS',
#   u'-',
#   u'3D',
#   u'YOSEOP',
#   u'USB',
#   u'\n'],
#  [u'https://t.co/EOfBdVQUfO', u'\n'],
#  [u'@ViGiGu', u'google', u'it', u':)', u'simple', u'\n'],
#  [u'nerd', u'ass', u'girl', u' ', u'https://t.co/T7kDirxPEL', u'\n'],
#  [u'LeadCorp',
#   u'Media',
#   u'@leadcorpmedia',
#   u'_',
#   u' ',
#   u'https://t.co/vRJG9Xnzw8',
#   u'\n'],
#  [u'RT',
#   u'mackdrama1017',
#   u':',
#   u'ChieMoney',
#   u'use',
#   u'google',
#   u'and',
#   u'learn',
#   u'how',
#   u'to',
#   u'!',
#   u'\n'],
#  [u'@ShaffieWeru',
#   u'Morning',
#   u'bro',
#   u'here',
#   u'be',
#   u'my',
#   u'new',
#   u'video',
#   u'i',
#   u'ne',
#   u'yr',
#   u'help',
#   u'i',
#   u'be',
#   u'talented',
#   u'bt',
#   u'i',
#   u'lack',
#   u'a',
#   u'manager',
#   u'bro',
#   u'https://t.co/NTs3QM5YU5',
#   u'\n'],
#  [u'Google', u'Play', u'Gift', u'Card', u'Code', u'\n'],
#  [u'claim',
#   u'your',
#   u'Google',
#   u'Play',
#   u'Gift',
#   u'Card',
#   u'Code',
#   u'...',
#   u'https://t.co/ySYH1x5kQl',
#   u'#',
#   u'amazon',
#   u'#',
#   u'itunes',
#   u'#',
#   u'googl',
#   u'\u2026',
#   u'https://t.co/ayDI4X1FKO',
#   u'\n'],
#  [u'@rizsrug216',
#   u'@tpaquette_IID',
#   u'Per',
#   u'https://t.co/jTlhLW8Ry5',
#   u'(',
#   u'sorry',
#   u')',
#   u',',
#   u'St.',
#   u'Devs',
#   u'for',
#   u'the',
#   u'sport',
#   u'come',
#   u'to',
#   u':',
#   u'\n'],
#  [u'Baseball', u':', u'.039', u'\n'],
#  [u'Football', u':', u'.125', u'\n'],
#  [u'King',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'.',
#   u'Summon',
#   u'today',
#   u'.',
#   u'App',
#   u'Store',
#   u':',
#   u'https://t.co/XeEuOEaXEG',
#   u'Google',
#   u'play',
#   u':',
#   u'https://t.co/vYQdbhrNEb',
#   u'#',
#   u'DarkSummoner',
#   u'\n'],
#  [u'King',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'.',
#   u'Summon',
#   u'today',
#   u'.',
#   u'App',
#   u'Store',
#   u':',
#   u'https://t.co/1ce13KchYS',
#   u'Google',
#   u'play',
#   u':',
#   u'https://t.co/IkkkXuEu9Q',
#   u'#',
#   u'DarkSummoner',
#   u'\n'],
#  [u'@PolitiBunny',
#   u'@PhillipJHill89',
#   u'you',
#   u'should',
#   u'go',
#   u'read',
#   u'a',
#   u'publish',
#   u'article',
#   u'that',
#   u'Russell',
#   u'Simmons',
#   u'write',
#   u'him',
#   u'google',
#   u'it',
#   u'\n'],
#  [u'I',
#   u'have',
#   u'enter',
#   u'to',
#   u'win',
#   u'a',
#   u'Google',
#   u'Nexus',
#   u'6P',
#   u'from',
#   u' ',
#   u'!',
#   u'   ',
#   u'https://t.co/4vFHfhaBey',
#   u'\n'],
#  [u'@moniimamz',
#   u'I',
#   u'know',
#   u'!',
#   u'I',
#   u'see',
#   u'it',
#   u'online',
#   u'like',
#   u'if',
#   u'u',
#   u'google',
#   u'the',
#   u'reviews',
#   u'for',
#   u'it',
#   u'!',
#   u'\U0001f610',
#   u'\n'],
#  [u'RT',
#   u'@kamcb29',
#   u':',
#   u'I',
#   u'have',
#   u'enter',
#   u'to',
#   u'win',
#   u'a',
#   u'Google',
#   u'Nexus',
#   u'6P',
#   u'from',
#   u'@MakeUseOf',
#   u'!',
#   u'https://t.co/o30B9xG6Dx',
#   u'#',
#   u'giveaway',
#   u'#',
#   u'competition',
#   u'\n'],
#  [u'Yayyyyy',
#   u'thanks',
#   u'for',
#   u'the',
#   u'follow',
#   u'@YeahhImAFangirl',
#   u'\n'],
#  [u'I',
#   u'love',
#   u'your',
#   u'Google',
#   u'plus',
#   u'page',
#   u'with',
#   u'the',
#   u'other',
#   u'girls',
#   u'!',
#   u'\U0001f49c\U0001f606',
#   u'\n'],
#  [u'After',
#   u'I',
#   u'have',
#   u'Google',
#   u'&',
#   u'amp',
#   u';',
#   u'read',
#   u'a',
#   u'ton',
#   u'of',
#   u'articles',
#   u'on',
#   u'the',
#   u'same',
#   u'subject',
#   u',',
#   u'I',
#   u'remember',
#   u',',
#   u'I',
#   u'could',
#   u'have',
#   u'just',
#   u'search',
#   u'YouTube',
#   u'for',
#   u'this',
#   u'shit',
#   u'\U0001f620',
#   u'\n'],
#  [u'Week',
#   u'2',
#   u'Power',
#   u'Rankings\U0001f608',
#   u':',
#   u'https://t.co/1xfRayMvpX',
#   u'\n'],
#  [u'RT',
#   u'@ShowerThoughtts',
#   u':',
#   u'Apple',
#   u'have',
#   u'"',
#   u'air',
#   u'"',
#   u',',
#   u'Amazon',
#   u'have',
#   u'"',
#   u'Fire',
#   u'"',
#   u',',
#   u'Google',
#   u'have',
#   u'"',
#   u'earth',
#   u'"',
#   u',',
#   u'why',
#   u'do',
#   u"n't",
#   u'Microsoft',
#   u'have',
#   u'"',
#   u'water',
#   u'"',
#   u'?',
#   u'\n'],
#  [u'-Looks',
#   u'up',
#   u'on',
#   u'Google',
#   u"'",
#   u'MikexJeremy',
#   u"'",
#   u'secretly-',
#   u'&',
#   u'lt;33',
#   u';)',
#   u'[',
#   u'@FnafSchimdt,@MikeSchmit10,]#SenpaiBot~',
#   u'\n'],
#  [u'RT',
#   u'@_silentbent',
#   u'_',
#   u':',
#   u'go',
#   u'support',
#   u'@dadeputy',
#   u'single',
#   u'"',
#   u'It',
#   u'be',
#   u'Okay',
#   u'"',
#   u'feat',
#   u'@jaesongreen',
#   u'on',
#   u'iTunes',
#   u',',
#   u'Google',
#   u'\u2026',
#   u'https://t.co/WPc1jwFLs0',
#   u'\n'],
#  [u'Hi',
#   u',',
#   u'checkout',
#   u'this',
#   u'application',
#   u'.',
#   u'https://t.co/cpKpnbsTS7',
#   u'\n'],
#  [u'RT',
#   u'@glotevo',
#   u':',
#   u'nerd',
#   u'ass',
#   u'girl',
#   u' ',
#   u'https://t.co/T7kDirxPEL',
#   u'\n'],
#  [u'I',
#   u'be',
#   u'play',
#   u'My',
#   u'Singing',
#   u'Monsters',
#   u'.',
#   u'check',
#   u'it',
#   u'out',
#   u'!',
#   u'https://t.co/JrWWtmojWC',
#   u'\n'],
#  [u'Ever',
#   u'want',
#   u'to',
#   u'become',
#   u'a',
#   u'Google',
#   u'Small',
#   u'Business',
#   u'Advisor',
#   u'?',
#   u'Now',
#   u'you',
#   u'can',
#   u'!',
#   u'https://t.co/fcOkq6srSX',
#   u'\n'],
#  [u'check',
#   u'out',
#   u'@GCloudAndroid',
#   u'.',
#   u'Never',
#   u'worry',
#   u'about',
#   u'lose',
#   u'your',
#   u'#',
#   u'Android',
#   u'device',
#   u'up',
#   u'to',
#   u'10',
#   u'GB',
#   u'Free',
#   u'to',
#   u'backup',
#   u'https://t.co/7eaqZEHAnI',
#   u'\n'],
#  [u'Top',
#   u'Android',
#   u'Apps',
#   u'(',
#   u'without',
#   u'all',
#   u'the',
#   u'games',
#   u')',
#   u'reveal',
#   u'in',
#   u'hide',
#   u'Google',
#   u'Play',
#   u'Store',
#   u'link',
#   u'-',
#   u'\u2026',
#   u'https://t.co/7ZSs9MkcLm',
#   u'#',
#   u'Android',
#   u'#',
#   u'India',
#   u'\n'],
#  [u'RT',
#   u'@clashbabes',
#   u':',
#   u'Th8',
#   u'50vs50',
#   u'!',
#   u'come',
#   u'join',
#   u'the',
#   u'fun',
#   u'!',
#   u'https://t.co/mFgZlpU9M4',
#   u'\n'],
#  [u'https://t.co/0ElEQm917Q',
#   u'How',
#   u'To',
#   u'increase',
#   u'Blog',
#   u'Traffic',
#   u'With',
#   u'Google',
#   u'Plus',
#   u'-',
#   u'#',
#   u'Blogging',
#   u'#',
#   u'SMM',
#   u'#',
#   u'SocialMedia',
#   u'https://t.co/UIcEYNJ4u2',
#   u':',
#   u'OfficialChat',
#   u'\u2026',
#   u'\n'],
#  [u'RelNews', u':', u'\n'],
#  [u'                    ',
#   u'Europe',
#   u'could',
#   u'produce',
#   u'a',
#   u'Facebook',
#   u"'",
#   u'and',
#   u'the',
#   u'Google',
#   u'of',
#   u'healthcare',
#   u'\n'],
#  [u' ', u'-The', u'Daily', u'Telegraph-', u'https://t.co/C6J53DKUuU', u'\n'],
#  [u'RelNews', u':', u'\n'],
#  [u'                    ',
#   u'Europe',
#   u'could',
#   u'produce',
#   u'a',
#   u'Facebook',
#   u'\\',
#   u"'",
#   u'and',
#   u'the',
#   u'Google',
#   u'of',
#   u'healthcare',
#   u'\n'],
#  [u' ', u'-The', u'Daily', u'Telegraph-', u'https://t.co/C6J53DKUuU', u'\n'],
#  [u'New',
#   u'post',
#   u':',
#   u'Google',
#   u'Knowledge',
#   u'Graph',
#   u'Optimization',
#   u'Strategies',
#   u'for',
#   u'the',
#   u'New',
#   u'Year',
#   u'for',
#   u'Infographic',
#   u'Designers',
#   u'https://t.co/qsdAbq3HnD',
#   u'\n'],
#  [u'Anyone',
#   u'else',
#   u'spend',
#   u'the',
#   u'entire',
#   u'time',
#   u'drive',
#   u'try',
#   u'to',
#   u'beat',
#   u'the',
#   u'original',
#   u'arrival',
#   u'time',
#   u'estimate',
#   u'from',
#   u'Google',
#   u'Maps',
#   u'?',
#   u'\U0001f643',
#   u'\n'],
#  [u'#',
#   u'DESIGN',
#   u':',
#   u'Font',
#   u'of',
#   u'the',
#   u'day',
#   u':',
#   u'Mecka',
#   u'https://t.co/9iI2KGZ0ZH',
#   u'#',
#   u'design',
#   u'\n'],
#  [u'Google',
#   u',',
#   u'you',
#   u'have',
#   u'fail',
#   u'me',
#   u'for',
#   u'the',
#   u'first',
#   u'time',
#   u'!',
#   u'Why',
#   u'can',
#   u"n't",
#   u'you',
#   u'tell',
#   u'me',
#   u'what',
#   u'these',
#   u'crystals',
#   u'be',
#   u'inside',
#   u'my',
#   u'plum',
#   u'?',
#   u'https://t.co/vXmONcnTom',
#   u'\n'],
#  [u'RT',
#   u'@rougek68',
#   u':',
#   u'On',
#   u'the',
#   u'Meaning',
#   u'of',
#   u'#',
#   u'Fascism',
#   u'https://t.co/jfoIA7jcS9',
#   u'\n'],
#  [u'#', u'USA', u'#', u'israel', u'\n'],
#  [u'We',
#   u'be',
#   u'All',
#   u'#',
#   u'Fascists',
#   u'Now',
#   u'https://t.co/NEQYZufaBV',
#   u'\n'],
#  [u'Time', u'U', u'kno', u'\u2026', u'\n'],
#  [u'Google', u'#', u'Team2PM', u'\n'],
#  [u'RT',
#   u'@clashbabes',
#   u':',
#   u'Th8',
#   u'50vs50',
#   u'!',
#   u'come',
#   u'join',
#   u'the',
#   u'fun',
#   u'!',
#   u'https://t.co/mFgZlpU9M4',
#   u'\n'],
#  [u'The',
#   u'first',
#   u'time',
#   u'someone',
#   u'comment',
#   u'"',
#   u'Schwing',
#   u'!',
#   u'"',
#   u'on',
#   u'one',
#   u'of',
#   u'my',
#   u'selfies',
#   u',',
#   u'I',
#   u'have',
#   u'to',
#   u'google',
#   u'what',
#   u'it',
#   u'be',
#   u'.',
#   u'It',
#   u'be',
#   u'basically',
#   u'an',
#   u'old',
#   u'guy',
#   u'compliment',
#   u'you',
#   u'.',
#   u'\n'],
#  [u'RT',
#   u'@_rachaelmcclung',
#   u':',
#   u'Brain',
#   u':',
#   u'go',
#   u'to',
#   u'sleep',
#   u'its',
#   u'10',
#   u'pm',
#   u'you',
#   u'now',
#   u'have',
#   u'a',
#   u'decent',
#   u'8',
#   u'hours',
#   u'of',
#   u'sleep',
#   u'..',
#   u'\n'],
#  [u'Me',
#   u':',
#   u'stay',
#   u'up',
#   u'to',
#   u'google',
#   u'different',
#   u'food',
#   u'recipes',
#   u'for',
#   u'\u2026',
#   u'\n'],
#  [u'RT',
#   u'https://t.co/s2HOfLUV2t',
#   u'#',
#   u'Google',
#   u"'",
#   u'#',
#   u'Android',
#   u'N',
#   u"'",
#   u'will',
#   u'Not',
#   u'use',
#   u'#',
#   u'Oracle',
#   u"'s",
#   u' ',
#   u'#',
#   u'Java',
#   u'APIs',
#   u' ',
#   u'https://t.co/fBMNzW4wdT',
#   u'gunjanraik',
#   u'\n'],
#  [u'RT',
#   u'https://t.co/HqV9jSb6In',
#   u'Android',
#   u'application',
#   u'relate',
#   u'to',
#   u'google',
#   u'maps',
#   u'--',
#   u'2',
#   u'by',
#   u'nsatheeshk',
#   u':',
#   u'need',
#   u'to',
#   u'update',
#   u'the',
#   u'Android',
#   u'Mobil',
#   u'...',
#   u'\u2026',
#   u'\n'],
#  [u'My',
#   u'mini',
#   u'just',
#   u'go',
#   u'to',
#   u'th9',
#   u'\U0001f622',
#   u'but',
#   u'this',
#   u'will',
#   u'be',
#   u'a',
#   u'fun',
#   u'event',
#   u'for',
#   u'any',
#   u'th8s',
#   u'out',
#   u'there',
#   u'!',
#   u'!',
#   u'https://t.co/5w4A07lZDs',
#   u'\n'],
#  [u'#',
#   u'OldRocks',
#   u'-',
#   u'#',
#   u'StructuresLeftBehind',
#   u':',
#   u'#',
#   u'PreDeluge',
#   u'Ancient',
#   u'#',
#   u'MicroSculpture',
#   u'To',
#   u'Massive',
#   u'Face',
#   u'&',
#   u'amp',
#   u';',
#   u'Shape',
#   u'#',
#   u'Iconography',
#   u'Remain',
#   u'https://t.co/nFd2nXEtGh',
#   u'\n'],
#  [u'@ImbruedJoint',
#   u'Hector',
#   u'have',
#   u'softly',
#   u'tilt',
#   u'his',
#   u'head',
#   u'towards',
#   u'Stuart',
#   u'in',
#   u'a',
#   u'confused',
#   u'sort',
#   u'of',
#   u'way',
#   u'.',
#   u'"',
#   u'What',
#   u'be',
#   u'Google',
#   u'?',
#   u'"',
#   u'He',
#   u'could',
#   u"n't",
#   u'possibly',
#   u'know',
#   u'what',
#   u'--',
#   u'\n'],
#  [u'Good',
#   u'domain',
#   u'possibility',
#   u'?',
#   u':',
#   u'www',
#   u'.',
#   u'West',
#   u'Virginia',
#   u'https://t.co/xi1QYKRHNt',
#   u'?',
#   u'?',
#   u'Its',
#   u'trending',
#   u'on',
#   u'google',
#   u'...',
#   u'\n'],
#  [u'Here',
#   u'man',
#   u'@TheRealLogs1996',
#   u'when',
#   u'you',
#   u'talk',
#   u'about',
#   u'how',
#   u'the',
#   u'Cubs',
#   u'win',
#   u'last',
#   u'year',
#   u' ',
#   u'https://t.co/NGbZGA7DP6',
#   u'\n'],
#  [u'Google',
#   u'Knowledge',
#   u'Graph',
#   u'Optimization',
#   u'Strategies',
#   u'for',
#   u'the',
#   u'New',
#   u'Year',
#   u'for',
#   u'Infographic',
#   u'\xa0',
#   u'Designers',
#   u'https://t.co/wJMnQtv4Rx',
#   u'https://t.co/jyIZemYUGH',
#   u'\n'],
#  [u'LebanonHashtag',
#   u':',
#   u'RT',
#   u'probrandz',
#   u':',
#   u'#',
#   u'Facebook',
#   u'Open',
#   u'Sources',
#   u'Artificial',
#   u'#',
#   u'Intelligence',
#   u'Servers',
#   u'Before',
#   u'#',
#   u'Google',
#   u'|',
#   u'Re',
#   u'/',
#   u'code',
#   u'https://t.co/f8RTJxEzSx',
#   u'\n'],
#  [u'#', u'di', u'\u2026', u'\n'],
#  [u'@r0thejan',
#   u'earn',
#   u'free',
#   u'Google',
#   u'Play',
#   u'and',
#   u'many',
#   u'more',
#   u'Giftcards',
#   u'at',
#   u'our',
#   u'fresh',
#   u'publish',
#   u'Website',
#   u'https://t.co/zPQb0lfDs9',
#   u'https://t.co/udIaPeF945',
#   u'\n'],
#  [u'KalGuntuku',
#   u':',
#   u'RT',
#   u'bunnymiilk',
#   u'"',
#   u'RT',
#   u'30seclovelive',
#   u':',
#   u'[',
#   u'RT',
#   u'to',
#   u'win',
#   u'!',
#   u']',
#   u'30',
#   u'Seconds',
#   u'of',
#   u'Love',
#   u'Live',
#   u'!',
#   u'5k',
#   u'Followers',
#   u'Giveaway',
#   u'#',
#   u'1',
#   u':',
#   u'$',
#   u'25',
#   u'iTunes',
#   u'/',
#   u'Google',
#   u'play',
#   u'gift',
#   u'ca',
#   u'\u2026',
#   u'\n'],
#  [u'RT',
#   u'@FortuneMagazine',
#   u':',
#   u'Here',
#   u'\u2019s',
#   u'how',
#   u'Google',
#   u'be',
#   u'take',
#   u'on',
#   u'Uber',
#   u'in',
#   u'2016',
#   u'https://t.co/X5STl6P5Xh',
#   u'\n'],
#  [u'[',
#   u'Minecraft',
#   u']',
#   u'I',
#   u'google',
#   u'"',
#   u'Natural',
#   u'arch',
#   u'"',
#   u'and',
#   u'a',
#   u'Minecraft',
#   u'image',
#   u'pop',
#   u'up',
#   u'for',
#   u'a',
#   u'real',
#   u'geographical',
#   u'scenic',
#   u'spot',
#   u'by',
#   u'Skandal',
#   u'\u2026',
#   u'https://t.co/9ZZrZrfJpP',
#   u'\n'],
#  [u'shenbrood',
#   u':',
#   u'What',
#   u'be',
#   u'your',
#   u'greatest',
#   u'#',
#   u'digitalmarketing',
#   u'#',
#   u'contentmarket',
#   u'blunder',
#   u'?',
#   u' ',
#   u'Well',
#   u'for',
#   u'me',
#   u'it',
#   u'be',
#   u'the',
#   u'ever',
#   u'change',
#   u'Google',
#   u'algorith',
#   u'.',
#   u' ',
#   u'What',
#   u'abo',
#   u'\u2026',
#   u'\n'],
#  [u'https://t.co/tkiiygFXRd',
#   u'What',
#   u'each',
#   u'state',
#   u'#',
#   u'Google',
#   u'd',
#   u'more',
#   u'than',
#   u'...',
#   u'#',
#   u'me',
#   u'#',
#   u'love',
#   u'#',
#   u'picoftheday',
#   u'#',
#   u'follow',
#   u'\n'],
#  [u'@hadley_delducaa',
#   u'google',
#   u'a',
#   u'wolf',
#   u'hybrid',
#   u'its',
#   u'my',
#   u'future',
#   u'dog',
#   u'\n'],
#  [u'Europe',
#   u'could',
#   u'produce',
#   u'a',
#   u'Facebook',
#   u'-',
#   u'and',
#   u'the',
#   u'Google',
#   u'of',
#   u'healthcare',
#   u'https://t.co/xEwaWcPRNF',
#   u'\n'],
#  [u'I',
#   u'have',
#   u'unlock',
#   u'a',
#   u'new',
#   u'area',
#   u'of',
#   u'my',
#   u'Island',
#   u'!',
#   u'https://t.co/gmGshSxtLG',
#   u'#',
#   u'Gameinsight',
#   u'#',
#   u'Android',
#   u'#',
#   u'Androidgames',
#   u'\n'],
#  [u'https://t.co/GVac2xs9OO',
#   u'get',
#   u'it',
#   u':',
#   u'Google',
#   u"'s",
#   u'latest',
#   u'free',
#   u'Android',
#   u'wallpaper',
#   u'show',
#   u'useful',
#   u'phone',
#   u'...',
#   u'https://t.co/KdbaKUYglP',
#   u'#',
#   u'Android',
#   u'\n'],
#  [u'I',
#   u'have',
#   u'reach',
#   u'level',
#   u'28',
#   u'.',
#   u'I',
#   u'earn',
#   u'\xa0',
#   u'$',
#   u'123000',
#   u'and',
#   u'\u20ac',
#   u'3',
#   u'!',
#   u'https://t.co/5qOLKlLp9K',
#   u'#',
#   u'Gameinsight',
#   u'#',
#   u'Androidgames',
#   u'#',
#   u'Android',
#   u'\n'],
#  [u'make',
#   u'sure',
#   u'your',
#   u'siwe',
#   u'ishkeep',
#   u'xsers',
#   u'mn',
#   u'thxir',
#   u'preferred',
#   u'ver|ion',
#   u' ',
#   u'fkyourmwebsite',
#   u'for',
#   u'tceir',
#   u'entule',
#   u'vtsiq',
#   u'.',
#   u'(',
#   u'Google',
#   u'Webmcstervkx',
#   u'\n'],
#  [u'RT',
#   u'@ladybirdcoc',
#   u':',
#   u'My',
#   u'mini',
#   u'just',
#   u'go',
#   u'to',
#   u'th9',
#   u'\U0001f622',
#   u'but',
#   u'this',
#   u'will',
#   u'be',
#   u'a',
#   u'fun',
#   u'event',
#   u'for',
#   u'any',
#   u'th8s',
#   u'out',
#   u'there',
#   u'!',
#   u'!',
#   u'https://t.co/5w4A07lZDs',
#   u'\n'],
#  [u'#',
#   u'NFL',
#   u'#',
#   u'MarshawnLynch',
#   u'2013',
#   u'"',
#   u'NFC',
#   u'Champ',
#   u'game',
#   u'"',
#   u'MARSHAWN',
#   u'LYNCH',
#   u'Touchdown',
#   u'Run',
#   u'Seattle',
#   u'Seahawks',
#   u'8x10',
#   u'photo',
#   u'https://t.co/tnS1K7aZFS',
#   u'#',
#   u'Seahawks',
#   u'#',
#   u'Google',
#   u'\n'],
#  [u'@chocolateluvah',
#   u'completely',
#   u'agree',
#   u'it',
#   u'be',
#   u'kill',
#   u'me',
#   u'not',
#   u'to',
#   u'google',
#   u'the',
#   u'case',
#   u'haha',
#   u'\n'],
#  [u'@JedDzn',
#   u'@IvanOfficial',
#   u'_',
#   u'_',
#   u'@picardonoel',
#   u'what',
#   u's',
#   u'that',
#   u'?',
#   u'*',
#   u'do',
#   u'nt',
#   u'ask',
#   u'me',
#   u'to',
#   u'google',
#   u'it',
#   u'*',
#   u'\n'],
#  [u'RT',
#   u'@seosanjayupadhy',
#   u':',
#   u'Alt',
#   u'+',
#   u'6',
#   u'.......',
#   u'\u2660',
#   u'.....',
#   u's\xacpade',
#   u'Alt',
#   u'+',
#   u'5',
#   u'.......',
#   u'\u2663',
#   u'......',
#   u'\xacClub',
#   u'Alt',
#   u'+',
#   u'3',
#   u'.............',
#   u'\xacHeart',
#   u'Alt',
#   u'+',
#   u'4',
#   u'.......',
#   u'\u2666',
#   u'......',
#   u'\xacDiamond',
#   u'\u2026',
#   u'htt',
#   u'\u2026',
#   u'\n'],
#  [u'RT',
#   u'@chrismessina',
#   u':',
#   u'tell',
#   u'me',
#   u'that',
#   u'Zuck',
#   u'be',
#   u"n't",
#   u'plan',
#   u'to',
#   u'take',
#   u'on',
#   u'Google',
#   u'with',
#   u'Messenger',
#   u'...',
#   u'#',
#   u'ConvComm',
#   u' ',
#   u'https://t.co/2ludfQPLTl',
#   u'https://t.co/8QbN',
#   u'\u2026',
#   u'\n'],
#  [u'second',
#   u'.',
#   u'When',
#   u'I',
#   u'be',
#   u'tweet',
#   u',',
#   u'I',
#   u'have',
#   u'always',
#   u'get',
#   u'my',
#   u'Google',
#   u'Docs',
#   u'open',
#   u'as',
#   u'well',
#   u'.',
#   u'#',
#   u'amwrit',
#   u'https://t.co/cIA8OVoKSE',
#   u'\n'],
#  [u'https://t.co/wiRZHnHUYV',
#   u'RT',
#   u'ShowerThoughtts',
#   u':',
#   u'Apple',
#   u'have',
#   u'"',
#   u'air',
#   u'"',
#   u',',
#   u'Amazon',
#   u'have',
#   u'"',
#   u'Fire',
#   u'"',
#   u',',
#   u'Google',
#   u'have',
#   u'"',
#   u'earth',
#   u'"',
#   u',',
#   u'why',
#   u'do',
#   u"n't",
#   u'M',
#   u'\u2026',
#   u'https://t.co/O69Q8NpBmK',
#   u'\n'],
#  [u'@luckyberry96',
#   u'go',
#   u'to',
#   u'this',
#   u'website',
#   u'.',
#   u'https://t.co/4O42egV2MV',
#   u'copy',
#   u'and',
#   u'paste',
#   u'it',
#   u'in',
#   u'twitter',
#   u'.',
#   u'Tweet',
#   u'more',
#   u'for',
#   u'#',
#   u'TeamSeventeen',
#   u'\n'],
#  [u'@victoria_stee',
#   u'u',
#   u'+',
#   u'google',
#   u"'s",
#   u'instructions',
#   u'just',
#   u'save',
#   u'my',
#   u'life\U0001f618',
#   u'\n'],
#  [u'RT',
#   u'@KunalChoudhary',
#   u'_',
#   u':',
#   u'Pathankot',
#   u'attack',
#   u':',
#   u'Youth',
#   u'Congress',
#   u'members',
#   u'burn',
#   u'Sharifs',
#   u'effigy',
#   u'in',
#   u'Bhopal',
#   u'https://t.co/n3uftphdsx',
#   u'(',
#   u'@IndiaToday',
#   u')',
#   u'\n'],
#  [u'@RajaBrar', u'\u2026', u'\n'],
#  [u'https://t.co/rbIrlQpYMx',
#   u'ALSO',
#   u'HERE',
#   u'IT',
#   u'be',
#   u'MY',
#   u'REVAMPED',
#   u'AND',
#   u'MUCH',
#   u'BETTER',
#   u'GOT7',
#   u'PRIMER',
#   u'SHARE',
#   u'OUR',
#   u'BOYS',
#   u'WITH',
#   u'THE',
#   u'WORLD',
#   u'\n'],
#  [u'I',
#   u'have',
#   u'enter',
#   u'to',
#   u'win',
#   u'a',
#   u'Google',
#   u'Nexus',
#   u'6P',
#   u'from',
#   u'@MakeUseOf',
#   u'!',
#   u'https://t.co/tiM479eSDN',
#   u'#',
#   u'giveaway',
#   u'#',
#   u'competition',
#   u'\n'],
#  [u'New',
#   u'Mobile',
#   u'Apps',
#   u'on',
#   u'#',
#   u'PlayStore',
#   u'#',
#   u'Android',
#   u':',
#   u'Gods',
#   u'Of',
#   u'Rome',
#   u',',
#   u'cut',
#   u'The',
#   u'Rope',
#   u',',
#   u'Gun',
#   u'Simulator',
#   u',',
#   u'KitWall',
#   u'etc',
#   u'.Check',
#   u'More',
#   u'on',
#   u'https://t.co/BszRb7JO4E',
#   u'\n'],
#  [u'Any', u'other', u'takers', u'?', u'https://t.co/J0DhhMF9T4', u'\n'],
#  [u'GoogleExpertUK',
#   u':',
#   u'#',
#   u'Google',
#   u'support',
#   u'Swedish',
#   u'Chef',
#   u'from',
#   u'The',
#   u'Muppets',
#   u'!',
#   u'MuppetsStudio',
#   u'#',
#   u'internet',
#   u'#',
#   u'\u2026',
#   u'https://t.co/pUrY7IHU4y',
#   u')',
#   u'https://t.co/e43mzDlDzw',
#   u'\n'],
#  [u'ECO',
#   u'100',
#   u'WK',
#   u'10',
#   u'CHAPTER',
#   u'18',
#   u'HOMEWORK',
#   u'-',
#   u'https://t.co/BURTA5bO3w',
#   u'\n'],
#  [u'@WinterFNmute665',
#   u'@RT_America',
#   u'look',
#   u'up',
#   u'militia',
#   u'too',
#   u',',
#   u'second',
#   u'definition',
#   u'on',
#   u'google',
#   u'.',
#   u'\n'],
#  [u'do',
#   u"n't",
#   u'google',
#   u'Any',
#   u'Of',
#   u'These',
#   u'Terms',
#   u'No',
#   u'Matter',
#   u'How',
#   u'Bad',
#   u'You',
#   u'want',
#   u'To',
#   u'!',
#   u'...',
#   u'https://t.co/vfcd3RHdYM',
#   u'\n'],
#  [u'KalGuntuku',
#   u':',
#   u'RT',
#   u'bunnymiilk',
#   u'"',
#   u'RT',
#   u'30seclovelive',
#   u':',
#   u'[',
#   u'RT',
#   u'to',
#   u'win',
#   u'!',
#   u']',
#   u'30',
#   u'Seconds',
#   u'of',
#   u'Love',
#   u'Live',
#   u'!',
#   u'5k',
#   u'Followers',
#   u'Giveaway',
#   u'#',
#   u'1',
#   u':',
#   u'$',
#   u'25',
#   u'i',
#   u'\u2026',
#   u'https://t.co/jtvcWEI0SV',
#   u'\n'],
#  [u'@ohitsmrcreeper',
#   u'@SapphireGinger',
#   u'oh',
#   u'thank',
#   u'god',
#   u'google',
#   u'translate',
#   u'be',
#   u'wrong',
#   u'\n'],
#  [u'RT',
#   u'@CarlaLioness',
#   u':',
#   u'\u2714TWEETSHEET\u27a1PETITIONS',
#   u'-',
#   u'PART',
#   u'3\u2714',
#   u'SUPPORT',
#   u'THE',
#   u'FIGHT',
#   u'AGAINST',
#   u'DOG&amp;CAT',
#   u'#',
#   u'MEATINDUSTRY',
#   u'IN',
#   u'#',
#   u'SouthKorea',
#   u'https://t.co/TKildjZJNr',
#   u'http',
#   u'\u2026',
#   u'\n'],
#  [u'Google', u'Maps', u'https://t.co/dU4PD1ch4V', u'\n'],
#  [u'@Xen_Games',
#   u'Google',
#   u'do',
#   u"n't",
#   u'say',
#   u'what',
#   u'5',
#   u'out',
#   u'7',
#   u'mean',
#   u'why',
#   u'not',
#   u'7',
#   u'out',
#   u'of',
#   u'7',
#   u'?',
#   u'?',
#   u'?',
#   u'?',
#   u'?',
#   u'\n'],
#  [u'@MakingStarWars',
#   u'Ugh',
#   u'.',
#   u'The',
#   u'rights',
#   u'sign',
#   u'mess',
#   u'up',
#   u'the',
#   u'link',
#   u'.',
#   u'Google',
#   u"'",
#   u'force',
#   u'awaken',
#   u'70',
#   u'mm',
#   u"'",
#   u'and',
#   u'the',
#   u'IMAX',
#   u'link',
#   u'should',
#   u'send',
#   u'you',
#   u'there',
#   u'.',
#   u'\n'],
#  [u'RT',
#   u'@dinowoowife',
#   u':',
#   u'[',
#   u'MY',
#   u']',
#   u'BTS',
#   u'2ND',
#   u'MUSTER',
#   u'SLOGAN',
#   u'"',
#   u'\ub450\uadfc\uac74',
#   u'"',
#   u'BY',
#   u'VISUAL',
#   u'shock',
#   u'@VShock1230',
#   u'https://t.co/SpccZhS5mk',
#   u'https://t.co/kOiqxiSZYk',
#   u'\n'],
#  [u'LebanonHashtag',
#   u':',
#   u'RT',
#   u'probrandz',
#   u':',
#   u'#',
#   u'Facebook',
#   u'Open',
#   u'Sources',
#   u'Artificial',
#   u'#',
#   u'Intelligence',
#   u'Servers',
#   u'Before',
#   u'#',
#   u'Google',
#   u'|',
#   u'Re',
#   u'/',
#   u'code',
#   u'https://t.co/VgWBxAG52q',
#   u'\n'],
#  [u'#', u'di', u'\u2026', u'\n'],
#  [u'RT',
#   u'@TheMoneyGenie',
#   u':',
#   u'Why',
#   u'PayPal',
#   u'.',
#   u'Me',
#   u'be',
#   u'So',
#   u'Infuriating',
#   u'(',
#   u'But',
#   u'I',
#   u'be',
#   u'use',
#   u'It',
#   u'Anyway',
#   u')',
#   u' ',
#   u'work',
#   u'from',
#   u'home',
#   u'https://t.co/JeP3833l2i',
#   u'https://t.co/RFJhUsiy7Z',
#   u'\n'],
#  [u'Ford',
#   u'add',
#   u'Apple',
#   u'CarPlay',
#   u'and',
#   u'Android',
#   u'Auto',
#   u'to',
#   u'Sync',
#   u'3',
#   u',',
#   u'...',
#   u'https://t.co/NSPCS9KHWE',
#   u'#',
#   u'google',
#   u'|',
#   u'https://t.co/MZBQSll3dP',
#   u'https://t.co/tHKibTMDlU',
#   u'\n'],
#  [u'Best',
#   u'colour',
#   u'for',
#   u'zodiac',
#   u'sign',
#   u'in',
#   u'year',
#   u'2016',
#   u'\n'],
#  [u'https://t.co/WHqjhaywhq', u'\n'],
#  [u'@ShaffieWeru',
#   u'hi',
#   u'bro',
#   u'i',
#   u'ne',
#   u'your',
#   u'help',
#   u'here',
#   u'be',
#   u'my',
#   u'new',
#   u'video',
#   u'..',
#   u'can',
#   u'you',
#   u'manage',
#   u'me',
#   u'bro',
#   u'https://t.co/NTs3QM5YU5',
#   u'\n'],
#  [u'try',
#   u'TwitGrow',
#   u'for',
#   u'Twitter',
#   u'!',
#   u'get',
#   u'1000',
#   u'+',
#   u'REAL',
#   u'followers',
#   u',',
#   u'retweets',
#   u'and',
#   u'favorites',
#   u'!',
#   u'Google',
#   u'Play',
#   u':',
#   u'https://t.co/v5qI6nbcZt',
#   u'https://t.co/s5wKVVeiCI',
#   u'\n'],
#  [u'RT',
#   u'@lw',
#   u':',
#   u'How',
#   u'To',
#   u'be',
#   u'The',
#   u'Person',
#   u'Who',
#   u'Never',
#   u'miss',
#   u'A',
#   u'Deadline',
#   u'https://t.co/jxsYcQpjII',
#   u'\n'],
#  [u'shenbrood',
#   u':',
#   u'What',
#   u'be',
#   u'your',
#   u'greatest',
#   u'#',
#   u'digitalmarketing',
#   u'#',
#   u'contentmarket',
#   u'blunder',
#   u'?',
#   u' ',
#   u'Well',
#   u'for',
#   u'me',
#   u'it',
#   u'be',
#   u'the',
#   u'ever',
#   u'change',
#   u'Google',
#   u'algorith',
#   u'.',
#   u' ',
#   u'What',
#   u'abo',
#   u'\u2026',
#   u'\n'],
#  [u'RT',
#   u'@dinowoowife',
#   u':',
#   u'[',
#   u'MY',
#   u']',
#   u'JIMIN',
#   u'2016',
#   u"'",
#   u'RISE',
#   u"'",
#   u'stock',
#   u'sale',
#   u'by',
#   u'MINingful',
#   u'moment',
#   u'@miningfulmoment',
#   u'\u2665',
#   u'https://t.co/DwRaGK45D3',
#   u'https://t.co/Nh04n1sB5b',
#   u'\n'],
#  [u'#',
#   u'creativitybooster',
#   u':',
#   u'Communicate',
#   u'stupid',
#   u'affiliate',
#   u'at',
#   u'Google',
#   u'.',
#   u'TOP',
#   u'10',
#   u'ideas',
#   u':',
#   u'https://t.co/9Dww7xv6t2',
#   u'#',
#   u'growthhacking',
#   u'#',
#   u'blogg',
#   u'\n'],
#  [u'#',
#   u'RADIO',
#   u'#',
#   u'TOP40',
#   u'Now',
#   u'play',
#   u'#',
#   u'shut',
#   u'Up',
#   u'#',
#   u'Stormzy',
#   u'#',
#   u'APPS',
#   u'Apple',
#   u'https://t.co/GIrJLsb5lM',
#   u'Google',
#   u'https://t.co/P24euDWBeU',
#   u'\n'],
#  [u'will',
#   u'Google',
#   u'do',
#   u'one',
#   u'of',
#   u'those',
#   u'semantically',
#   u'-',
#   u'aware',
#   u'auto',
#   u'-',
#   u'answers',
#   u'if',
#   u'I',
#   u'search',
#   u'"',
#   u'RZA',
#   u'Elo',
#   u'"',
#   u'?',
#   u'do',
#   u"n't",
#   u'wanna',
#   u'be',
#   u'disappointed',
#   u'\n'],
#  [u'Just',
#   u'like',
#   u'new',
#   u'college',
#   u'students',
#   u'be',
#   u'at',
#   u'risk',
#   u'for',
#   u'the',
#   u'Freshman',
#   u'15',
#   u',',
#   u'Google',
#   u'employees',
#   u'joke',
#   u'about',
#   u'the',
#   u'Google',
#   u'15',
#   u'from',
#   u'all',
#   u'the',
#   u'snaks',
#   u'available',
#   u'.',
#   u'\n'],
#  [u'Me',
#   u'af',
#   u'\U0001f602\U0001f602\U0001f602',
#   u'https://t.co/fUw8UrVIV0',
#   u'\n'],
#  [u'Spare',
#   u'mark',
#   u'as',
#   u'respect',
#   u'the',
#   u'google',
#   u'android',
#   u'scum',
#   u'yourself',
#   u'april',
#   u'au',
#   u'pair',
#   u'self',
#   u':',
#   u'skacV',
#   u'https://t.co/mjgyEDMeWw',
#   u'\n'],
#  [u'Google',
#   u'#',
#   u'Cardboard',
#   u'Used',
#   u'By',
#   u'Surgeons',
#   u'To',
#   u'perform',
#   u'Heart',
#   u'Surgery',
#   u'And',
#   u'Saves',
#   u'A',
#   u'Life',
#   u'https://t.co/LtMxdRcatV',
#   u'https://t.co/Zd6YAFTvUn',
#   u'\n'],
#  [u'RT',
#   u'@TheMoneyGenie',
#   u':',
#   u'Why',
#   u'spend',
#   u'Money',
#   u'Saves',
#   u'You',
#   u'Time',
#   u'(',
#   u'and',
#   u'Earns',
#   u'You',
#   u'More',
#   u'Money',
#   u')',
#   u' ',
#   u'work',
#   u'from',
#   u'home',
#   u'https://t.co/4hrngezka4',
#   u'https://t.co/2jjwyW',
#   u'\u2026',
#   u'\n'],
#  [u'This',
#   u'House',
#   u'be',
#   u'sell',
#   u'Dirt',
#   u'Cheap',
#   u',',
#   u'The',
#   u'Google',
#   u'Maps',
#   u'Picture',
#   u'Explains',
#   u'Exactly',
#   u'Why',
#   u'....',
#   u'https://t.co/6yJUWU1o9v',
#   u'\n'],
#  [u'Google', u'have', u'no', u'chill', u'https://t.co/Rs2QG2NXQa', u'\n'],
#  [u'RT',
#   u'@got7style',
#   u':',
#   u'[',
#   u'#',
#   u'B2GETHER',
#   u']',
#   u'GOT7',
#   u'with',
#   u'B',
#   u'Connect',
#   u'Bracelet',
#   u'\n'],
#  [u'#',
#   u'JB',
#   u' ',
#   u'#',
#   u'JACKSON',
#   u' ',
#   u'#',
#   u'TEAMGOT7',
#   u'#',
#   u'GOT7STYLE',
#   u'\n'],
#  [u'https://t.co/VCVVUZfGNU',
#   u'\u2026',
#   u'https://t.co/BueT9Zr',
#   u'\u2026',
#   u'\n'],
#  [u'Women',
#   u'rise',
#   u'in',
#   u'HP',
#   u'panchayat',
#   u'politics',
#   u'https://t.co/jo0pJfFB6X',
#   u'#',
#   u'HP',
#   u'\n'],
#  [u'Police',
#   u'condemn',
#   u'Facebook',
#   u'comments',
#   u'on',
#   u'Mount',
#   u'Maunganui',
#   u'New',
#   u'Year',
#   u"'s",
#   u'Eve',
#   u'page',
#   u'https://t.co/BaomUZeAw8',
#   u'#',
#   u'facebook',
#   u'\n'],
#  [u'wonder',
#   u'Which',
#   u'Food',
#   u'be',
#   u'Healthier',
#   u'Google',
#   u'have',
#   u'A',
#   u'Tool',
#   u'For',
#   u'\u2026',
#   u':',
#   u'https://t.co/HxOGzZ0Vfr',
#   u'...',
#   u'\n'],
#  [u'RT',
#   u'@f396',
#   u':',
#   u'Iran',
#   u'blame',
#   u'America',
#   u',',
#   u'Britain',
#   u'and',
#   u"'",
#   u'Zionists',
#   u"'",
#   u'for',
#   u'Nimr',
#   u'execution',
#   u'-',
#   u'https://t.co/BwXEicgAOA',
#   u'via',
#   u'https://t.co/UjStGmTT2f',
#   u'\n'],
#  [u'@trp_takumi', u'[', u'reply', u']', u'\n'],
#  [u'\n'],
#  [u'Gunakan', u'lah', u'google', u'translate', u',', u'lol', u'xD', u'\n'],
#  [u'Lifehacker',
#   u':',
#   u'run',
#   u'Windows',
#   u'on',
#   u'Your',
#   u'Mac',
#   u':',
#   u'VirtualBox',
#   u'vs',
#   u'VMware',
#   u'Fusion',
#   u'vs',
#   u'Parallels',
#   u'.',
#   u'https://t.co/OZFvvqpkEf',
#   u'\n'],
#  [u'The',
#   u'Polar',
#   u'Bears',
#   u'-',
#   u'Movies',
#   u'&',
#   u'amp',
#   u';',
#   u'TV',
#   u'on',
#   u'Google',
#   u'Play',
#   u'https://t.co/wkSSSKkHH6',
#   u'\n'],
#  [u'"',
#   u'become',
#   u'a',
#   u'Google',
#   u'Small',
#   u'Business',
#   u'Expert',
#   u'Advisor',
#   u'"',
#   u' ',
#   u'https://t.co/8GfXh7JZI8',
#   u'#',
#   u'inboundmarketing',
#   u'#',
#   u'feedly',
#   u'\n'],
#  [u'Gang',
#   u'knock',
#   u'down',
#   u'Cane',
#   u'Grove',
#   u'man',
#   u'then',
#   u'beat',
#   u'him',
#   u'to',
#   u'death',
#   u'https://t.co/EfTP6JbZS9',
#   u'#',
#   u'beat',
#   u'\n'],
#  [u'Ohio',
#   u'State',
#   u'basketball',
#   u'win',
#   u'sixth',
#   u'straight',
#   u',',
#   u'beat',
#   u'Illinois',
#   u'75',
#   u'-',
#   u'73',
#   u'https://t.co/uSeu3D1Byp',
#   u'#',
#   u'beat',
#   u'\n'],
#  [u'RT',
#   u'@newsycombinator',
#   u':',
#   u'Google',
#   u',',
#   u'HP',
#   u',',
#   u'Oracle',
#   u'Join',
#   u'RISC',
#   u'-',
#   u'V',
#   u'\u2013',
#   u'Open',
#   u'-',
#   u'source',
#   u'processor',
#   u'core',
#   u'gains',
#   u'traction',
#   u'https://t.co/8xnBu3TICr',
#   u'\n'],
#  [u'@_QueenLioness',
#   u'_',
#   u'@justinrgrrb',
#   u'@McDonald_Wes',
#   u'Sweet',
#   u'De',
#   u'-',
#   u'Lights',
#   u'Bakery',
#   u'Inc',
#   u'&',
#   u'lt;----',
#   u'this',
#   u'place',
#   u',',
#   u'google',
#   u'it',
#   u'...',
#   u'A++++++',
#   u'\n'],
#  [u'RT',
#   u'@f396',
#   u':',
#   u'Saudi',
#   u'Arabia',
#   u'sever',
#   u'diplomatic',
#   u'ties',
#   u'with',
#   u'Iran',
#   u'over',
#   u'embassy',
#   u'fire',
#   u'-',
#   u'https://t.co/r0iZugJa3v',
#   u'via',
#   u'https://t.co/UjStGmTT2f',
#   u'\n'],
#  [u'RT',
#   u'@TheMoneyGenie',
#   u':',
#   u'Why',
#   u'People',
#   u'Un',
#   u'-',
#   u'Follow',
#   u'You',
#   u'On',
#   u'Social',
#   u'Media',
#   u'Platforms',
#   u' ',
#   u'quick',
#   u'cash',
#   u'https://t.co/AlwvHy0mkz',
#   u'https://t.co/d3xZ63Xj8j',
#   u'\n'],
#  [u'@Mrkenneyy',
#   u'I',
#   u'see',
#   u'ur',
#   u'tweet',
#   u'no',
#   u'need',
#   u'for',
#   u'Google',
#   u'lol',
#   u'it',
#   u'be',
#   u'a',
#   u'very',
#   u'large',
#   u'dog',
#   u'\n'],
#  [u'New',
#   u'Google',
#   u'Chat',
#   u'App',
#   u'could',
#   u'destroy',
#   u'Facebook',
#   u'Messenger',
#   u'https://t.co/71Cu1vKcOI',
#   u'#',
#   u'google',
#   u'\n'],
#  [u'RT',
#   u'@lexicaaan',
#   u':',
#   u'Me',
#   u'af',
#   u'\U0001f602\U0001f602\U0001f602',
#   u'https://t.co/fUw8UrVIV0',
#   u'\n'],
#  [u'#',
#   u'RADIO',
#   u'#',
#   u'90s',
#   u'#',
#   u'juice',
#   u'Now',
#   u'play',
#   u'#',
#   u'Breathe',
#   u'(',
#   u'Radio',
#   u'Edit',
#   u')',
#   u'#',
#   u'MIDGE',
#   u'URE',
#   u'#',
#   u'APPS',
#   u'Apple',
#   u'https://t.co/gsMf7U2vzO',
#   u'Google',
#   u'https://t.co/idypaT7UqA',
#   u'\n'],
#  [u'@sebast_lj',
#   u'@McFaul',
#   u'@Inna4848',
#   u"'cause",
#   u'google',
#   u'translate',
#   u'it',
#   u'as',
#   u'"',
#   u'return',
#   u'to',
#   u'California',
#   u'"',
#   u'\n'],
#  [u'My',
#   u'Google',
#   u'Play',
#   u'account',
#   u'make',
#   u'me',
#   u'realize',
#   u'I',
#   u'be',
#   u'a',
#   u'dysfunctional',
#   u'teen',
#   u'with',
#   u'deep',
#   u'emotional',
#   u'scars',
#   u'.',
#   u'\n'],
#  [u'Latest',
#   u'Update',
#   u'Brings',
#   u'New',
#   u'Skills',
#   u'To',
#   u'The',
#   u'#',
#   u'AmazonEcho',
#   u'\n'],
#  [u'https://t.co/O6DxVu9zXy', u'https://t.co/zGNxP3vybq', u'\n'],
#  [u'RT',
#   u'@f396',
#   u':',
#   u"'",
#   u'Iran',
#   u'have',
#   u'a',
#   u'long',
#   u'record',
#   u'in',
#   u'attack',
#   u'foreign',
#   u'diplomatic',
#   u'missions',
#   u',',
#   u"'",
#   u'Saudi',
#   u'...',
#   u'-',
#   u'https://t.co/3gaSRB3osT',
#   u'via',
#   u'https://t.co/UjStGmTT2f',
#   u'\n'],
#  [u'RT',
#   u'shenbrood',
#   u'What',
#   u'be',
#   u'your',
#   u'greatest',
#   u'#',
#   u'digitalmarketing',
#   u'#',
#   u'contentmarket',
#   u'blunder',
#   u'?',
#   u' ',
#   u'Well',
#   u'for',
#   u'me',
#   u'it',
#   u'be',
#   u'the',
#   u'ever',
#   u'change',
#   u'Google',
#   u'algorith',
#   u'.',
#   u' ',
#   u'What',
#   u'a',
#   u'\u2026',
#   u'\n'],
#  [u'RT',
#   u'MasterMindDBS',
#   u'shenbrood',
#   u':',
#   u'What',
#   u'be',
#   u'your',
#   u'greatest',
#   u'#',
#   u'digitalmarketing',
#   u'#',
#   u'contentmarket',
#   u'blunder',
#   u'?',
#   u' ',
#   u'Well',
#   u'for',
#   u'me',
#   u'it',
#   u'be',
#   u'the',
#   u'ever',
#   u'change',
#   u'Google',
#   u'al',
#   u'\u2026',
#   u'\n'],
#  [u'https://t.co/eLiFeXQvA1', u'just', u'like', u'real', u'life', u'\n'],
#  [u'I',
#   u'like',
#   u'a',
#   u'@YouTube',
#   u'video',
#   u'https://t.co/52uUx0cXqW',
#   u'10',
#   u'Things',
#   u'You',
#   u'should',
#   u'Never',
#   u'Google',
#   u'(',
#   u'WARNING',
#   u'GROSS',
#   u')',
#   u'\n'],
#  [u'Here',
#   u'be',
#   u'what',
#   u'happen',
#   u'to',
#   u'@_snats',
#   u'when',
#   u'he',
#   u'can',
#   u'not',
#   u'access',
#   u'google',
#   u'translate',
#   u'\n'],
#  [u'https://t.co/EtprZXOGzD', u'\n'],
#  [u'RT',
#   u'@Kappa_Kappa',
#   u':',
#   u'The',
#   u'first',
#   u'time',
#   u'someone',
#   u'comment',
#   u'"',
#   u'Schwing',
#   u'!',
#   u'"',
#   u'on',
#   u'one',
#   u'of',
#   u'my',
#   u'selfies',
#   u',',
#   u'I',
#   u'have',
#   u'to',
#   u'google',
#   u'what',
#   u'it',
#   u'be',
#   u'.',
#   u'It',
#   u'be',
#   u'basically',
#   u'an',
#   u'old',
#   u'guy',
#   u'c',
#   u'\u2026',
#   u'\n'],
#  [u'RT',
#   u'@CarlaLioness',
#   u':',
#   u'\u2714TWEETSHEET\u27a1PETITIONS',
#   u'-',
#   u'PART',
#   u'3\u2714',
#   u'SUPPORT',
#   u'THE',
#   u'FIGHT',
#   u'AGAINST',
#   u'DOG&amp;CAT',
#   u'#',
#   u'MEATINDUSTRY',
#   u'IN',
#   u'#',
#   u'SouthKorea',
#   u'https://t.co/TKildjZJNr',
#   u'http',
#   u'\u2026',
#   u'\n'],
#  [u'RT',
#   u'SEOTraverseCity',
#   u'shenbrood',
#   u':',
#   u'What',
#   u'be',
#   u'your',
#   u'greatest',
#   u'#',
#   u'digitalmarketing',
#   u'#',
#   u'contentmarket',
#   u'blunder',
#   u'?',
#   u' ',
#   u'Well',
#   u'for',
#   u'me',
#   u'it',
#   u'be',
#   u'the',
#   u'ever',
#   u'change',
#   u'Google',
#   u'\u2026',
#   u'\n'],
#  [u'RT',
#   u'@NineLivesF',
#   u':',
#   u'A',
#   u'kitten',
#   u'call',
#   u'WANDA',
#   u'...',
#   u'\n'],
#  [u'Many',
#   u'of',
#   u'you',
#   u'have',
#   u'ask',
#   u'how',
#   u'WANDA',
#   u'come',
#   u'to',
#   u'be',
#   u'at',
#   u'Nine',
#   u'Lives',
#   u'Foundation',
#   u',',
#   u'pair',
#   u'up',
#   u'with',
#   u'\u2026',
#   u'https://t.co',
#   u'\u2026',
#   u'\n'],
#  [u'I',
#   u'have',
#   u'enter',
#   u'to',
#   u'win',
#   u'a',
#   u'Google',
#   u'Nexus',
#   u'6P',
#   u'from',
#   u'@MakeUseOf',
#   u'!',
#   u'https://t.co/l1VzzbljaW',
#   u'#',
#   u'giveaway',
#   u'#',
#   u'competition',
#   u'\n'],
#  [u'RT',
#   u'@CEEKTechnology',
#   u':',
#   u'Google',
#   u'#',
#   u'Nexus6P',
#   u'Review',
#   u'-',
#   u'#',
#   u'Android',
#   u'Overdose',
#   u'https://t.co/dmIouyVdVk',
#   u'via',
#   u'@bgdftw',
#   u'\n'],
#  [u'RT',
#   u'@got7style',
#   u':',
#   u'[',
#   u'#',
#   u'B2GETHER',
#   u']',
#   u'GOT7',
#   u'with',
#   u'B',
#   u'Connect',
#   u'Bracelet',
#   u'\n'],
#  [u'#',
#   u'JB',
#   u' ',
#   u'#',
#   u'JACKSON',
#   u' ',
#   u'#',
#   u'TEAMGOT7',
#   u'#',
#   u'GOT7STYLE',
#   u'\n'],
#  [u'https://t.co/VCVVUZfGNU',
#   u'\u2026',
#   u'https://t.co/BueT9Zr',
#   u'\u2026',
#   u'\n'],
#  [u'iRULU',
#   u'Tablet',
#   u'PC',
#   u'eXpro',
#   u'X1s',
#   u'7',
#   u'"',
#   u'8GB/1',
#   u'GB',
#   u'Google',
#   u'Android',
#   u'4.4',
#   u'Kitkat',
#   u'Quad',
#   u'Core',
#   u'Black',
#   u'-',
#   u'Bid',
#   u'Now',
#   u'!',
#   u'\u2026',
#   u'https://t.co/viBaz8kJeJ',
#   u'https://t.co/H4F9cY3Orq',
#   u'\n'],
#  [u'NEW',
#   u'IRULU',
#   u'7',
#   u'"',
#   u'Purple',
#   u'16',
#   u'GB',
#   u'Google',
#   u'Android',
#   u'4.4',
#   u'KitKat',
#   u'eXpro',
#   u'X1a',
#   u'HD',
#   u'Tablet',
#   u'Quad',
#   u'Core',
#   u'-',
#   u'Bid',
#   u'Now',
#   u'\u2026',
#   u'https://t.co/iVcQ3EAG9L',
#   u'https://t.co/3dOYcr12zX',
#   u'\n'],
#  [u'This',
#   u'House',
#   u'be',
#   u'For',
#   u'Sale',
#   u',',
#   u'And',
#   u'What',
#   u'Google',
#   u'Maps',
#   u'Caught',
#   u'Inside',
#   u'explain',
#   u'The',
#   u'C',
#   u'...',
#   u'https://t.co/nLCtPwNYXv',
#   u'https://t.co/MEL4kTftvK',
#   u'\n'],
#  [u'I',
#   u'just',
#   u'receive',
#   u'a',
#   u'reward',
#   u':',
#   u'An',
#   u'Apple',
#   u'a',
#   u'Day',
#   u'https://t.co/D5BMjL5RIs',
#   u'#',
#   u'Android',
#   u'#',
#   u'Androidgames',
#   u'#',
#   u'Gameinsight',
#   u'\n'],
#  [u'I',
#   u'just',
#   u'receive',
#   u'a',
#   u'reward',
#   u':',
#   u'An',
#   u'Apple',
#   u'a',
#   u'Day',
#   u'https://t.co/D5BMjL5RIs',
#   u'#',
#   u'Android',
#   u'#',
#   u'Gameinsight',
#   u'#',
#   u'Androidgames',
#   u'\n'],
#  [u'RT',
#   u'@dronelaws',
#   u':',
#   u'Status',
#   u'report',
#   u'on',
#   u'the',
#   u'NTIA',
#   u'multi',
#   u'-',
#   u'stakeholder',
#   u'drone',
#   u'privacy',
#   u'process',
#   u'.',
#   u'https://t.co/fN8JLkPty7',
#   u'\n'],
#  [u'braided',
#   u'beard',
#   u'-',
#   u'Google',
#   u'Search',
#   u'-',
#   u'#',
#   u'fashion',
#   u'#',
#   u'mensfashion',
#   u'#',
#   u'style',
#   u'https://t.co/OFWf8Tqutc',
#   u'https://t.co/HIIQ8uUG8J',
#   u'\n'],
#  [u'King',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'.',
#   u'Summon',
#   u'today',
#   u'.',
#   u'App',
#   u'Store',
#   u':',
#   u'https://t.co/8UfUVFoh4y',
#   u'Google',
#   u'play',
#   u':',
#   u'https://t.co/ZfelsWY2zH',
#   u'#',
#   u'DarkSummoner',
#   u'\n'],
#  [u'Google',
#   u'and',
#   u'Share',
#   u':',
#   u'YOUR',
#   u'RADIATION',
#   u'THIS',
#   u'WEEK',
#   u'\n'],
#  [u'and',
#   u'tell',
#   u'your',
#   u'friends',
#   u'and',
#   u'neighbors',
#   u';',
#   u'your',
#   u'governments',
#   u'already',
#   u'know',
#   u'!',
#   u'\n'],
#  [u'WE', u'...', u'https://t.co/aYtDQbG3O6', u'\n'],
#  [u'G+',
#   u':',
#   u'Somethings',
#   u'change',
#   u'as',
#   u'you',
#   u'no',
#   u'longer',
#   u'want',
#   u'to',
#   u'live',
#   u'within',
#   u'the',
#   u'same',
#   u'dusty',
#   u'hallways',
#   u'.',
#   u' ',
#   u'Thing',
#   u'be',
#   u'that',
#   u'as',
#   u'you',
#   u'clean',
#   u'up',
#   u'\u2026',
#   u'https://t.co/CD2Hb1VxDE',
#   u'\n'],
#  [u'Texas',
#   u'college',
#   u'student',
#   u'kill',
#   u'in',
#   u'New',
#   u'Year',
#   u"'s",
#   u'Eve',
#   u'shooting',
#   u'-',
#   u'CNN',
#   u'International',
#   u'\n'],
#  [u'https://t.co/NKVXMvg5Vs', u'\n'],
#  [u'https://t.co/57W1xcPUNv',
#   u'check',
#   u'out',
#   u'this',
#   u'page',
#   u'for',
#   u'the',
#   u'hottest',
#   u'music',
#   u'trends',
#   u'and',
#   u'more',
#   u',',
#   u'search',
#   u'your',
#   u'favorite',
#   u'music',
#   u'2',
#   u'https://t.co/g7gsLtZe0S',
#   u'\n'],
#  [u'https://t.co/EPop7HMqk3',
#   u'hey',
#   u'check',
#   u'out',
#   u'these',
#   u'2016',
#   u'amazon',
#   u'tips',
#   u'https://t.co/7OvQwnG3Qs',
#   u'\n'],
#  [u'New',
#   u'Event',
#   u'Now',
#   u'On',
#   u'.',
#   u'get',
#   u'New',
#   u'Rank',
#   u'S',
#   u'Monsters',
#   u'.',
#   u'App',
#   u'Store',
#   u':',
#   u'https://t.co/ioRDcpAe0t',
#   u'Google',
#   u'play',
#   u':',
#   u'https://t.co/3q1ftPNi3p',
#   u'#',
#   u'DarkSummoner',
#   u'\n'],
#  [u'RT', u'@GOPof_idiots', u':', u'@jeanettej', u'\n'],
#  [u'None', u'...', u'but', u'#', u'Bernie', u'do', u'!', u'\n'],
#  [u'https://t.co/t5sRAPBFvi', u'https://t.co/wZS2PR80QP', u'\n'],
#  [u'seem',
#   u'like',
#   u'my',
#   u'boss',
#   u'be',
#   u'interested',
#   u'enough',
#   u'in',
#   u'Chen',
#   u',',
#   u'he',
#   u'just',
#   u'google',
#   u'Chen',
#   u"'s",
#   u'pic',
#   u'and',
#   u'show',
#   u'it',
#   u'to',
#   u'me',
#   u'"',
#   u'be',
#   u'this',
#   u'Chen',
#   u'?',
#   u'He',
#   u'look',
#   u'like',
#   u'pondan',
#   u'.',
#   u'"',
#   u'\n'],
#  [u'RT',
#   u'@PYPRecords',
#   u':',
#   u'look',
#   u'us',
#   u'up',
#   u'on',
#   u'iTunes',
#   u'just',
#   u'google',
#   u'the',
#   u'name',
#   u'Popcorn',
#   u'PYP',
#   u'or',
#   u'come',
#   u'to',
#   u'NYC',
#   u'and',
#   u'ask',
#   u'for',
#   u'me',
#   u'https://t.co/4Xydj87TZk',
#   u'\n'],
#  [u'do',
#   u"n't",
#   u'google',
#   u'Any',
#   u'Of',
#   u'These',
#   u'Terms',
#   u'No',
#   u'Matter',
#   u'How',
#   u'Bad',
#   u'You',
#   u'want',
#   u'To',
#   u'!',
#   u'...',
#   u'https://t.co/F4o4XGbSpD',
#   u'\n'],
#  [u'@hadley_delducaa',
#   u'yeah',
#   u'but',
#   u'its',
#   u'worth',
#   u'a',
#   u'google',
#   u'https://t.co/ZdHrvt3VuE',
#   u'\n'],
#  [u'RT',
#   u'@darkenedsight',
#   u':',
#   u'Taylor',
#   u"'s",
#   u'gon',
#   u'na',
#   u'punch',
#   u'me',
#   u',',
#   u'now',
#   u'I',
#   u'have',
#   u'to',
#   u'google',
#   u'search',
#   u'how',
#   u'to',
#   u'act',
#   u'as',
#   u'if',
#   u'it',
#   u'hurt',
#   u'.',
#   u'Brb',
#   u'\U0001f607\U0001f606',
#   u'\n'],
#  [u'Pluralsight',
#   u'\u2013',
#   u'get',
#   u'start',
#   u'with',
#   u'Google',
#   u'Play',
#   u'In',
#   u'-',
#   u'app',
#   u'Billing',
#   u'https://t.co/PLmEvqWGdh',
#   u'\n'],
#  [u'@seedchan',
#   u'ill',
#   u'send',
#   u'you',
#   u'your',
#   u'card',
#   u'from',
#   u'tw',
#   u'!',
#   u'!',
#   u'https://t.co/AFhRYYUytH',
#   u'\n'],
#  [u'Not',
#   u'even',
#   u'google',
#   u'can',
#   u'help',
#   u'https://t.co/2sImxSyIP3',
#   u'\n'],
#  [u'not',
#   u'gon',
#   u'na',
#   u'lie',
#   u',',
#   u'I',
#   u'just',
#   u'type',
#   u'"',
#   u'what',
#   u'to',
#   u'wear',
#   u'when',
#   u'it',
#   u'be',
#   u'-15',
#   u'degrees',
#   u'on',
#   u'the',
#   u'outside',
#   u'"',
#   u'in',
#   u'google',
#   u'\n'],
#  [u'Samsung',
#   u':',
#   u'Dear',
#   u'samsung',
#   u'i',
#   u'be',
#   u'very',
#   u'annoyed',
#   u'i',
#   u'can',
#   u'not',
#   u'revert',
#   u'to',
#   u'kitkat',
#   u'from',
#   u'lollipop',
#   u'i',
#   u'have',
#   u'contact',
#   u'google',
#   u'my',
#   u'provider',
#   u'opt',
#   u'-',
#   u'https://t.co/MZn2AajhHf',
#   u'\n'],
#  [u'check',
#   u'out',
#   u'Gosford',
#   u'Park',
#   u'on',
#   u'https://t.co/dmGGQ8wiR6',
#   u'#',
#   u'hoopladigital',
#   u'\n'],
#  [u'British',
#   u'Mystery',
#   u'Robert',
#   u'Altman',
#   u'GREAT',
#   u'!',
#   u'Aleta',
#   u'\n'],
#  [u'\n'],
#  [u'https://t.co/ERHPlxkpTr', u'\n'],
#  [u'ECO',
#   u'100',
#   u'WK',
#   u'10',
#   u'QUIZ',
#   u'CHAPTERS',
#   u'16',
#   u'AND',
#   u'17',
#   u'-',
#   u'https://t.co/BURTA5bO3w',
#   u'\n'],
#  [u'@2pmphilippines',
#   u'pls',
#   u'help',
#   u'rt',
#   u'?',
#   u'^_^',
#   u'https://t.co/x4KmKmIL9R',
#   u'\n'],
#  [u'Google',
#   u"'s",
#   u'CEO',
#   u'think',
#   u'Vietnam',
#   u'-',
#   u'Home',
#   u'to',
#   u'the',
#   u'Next',
#   u'Big',
#   u'Startup',
#   u'Scene',
#   u'\n'],
#  [u'https://t.co/Z4pjChf85K', u'\n'],
#  [u'https://t.co/mZMkRLuuM5', u'https://t.co/gyq6YUXe0S', u'\n'],
#  [u'get',
#   u'your',
#   u'songs',
#   u'on',
#   u'iTunes',
#   u'/',
#   u'Google',
#   u'play',
#   u'etc',
#   u'\n'],
#  [u'RT',
#   u'@beautiigirls',
#   u':',
#   u'This',
#   u'House',
#   u'be',
#   u'For',
#   u'Sale',
#   u',',
#   u'Cheap',
#   u'.',
#   u'When',
#   u'You',
#   u'see',
#   u'What',
#   u'Google',
#   u'Maps',
#   u'Caught',
#   u',',
#   u'You',
#   u'will',
#   u'see',
#   u'Why',
#   u'!',
#   u'https://t.co/gAy9fc3q7s',
#   u'https://t.co',
#   u'\u2026',
#   u'\n'],
#  [u'@occamsboner',
#   u'@jonathanchait',
#   u'Instead',
#   u'of',
#   u'ask',
#   u'everyone',
#   u'on',
#   u'Twitter',
#   u',',
#   u' ',
#   u'why',
#   u'do',
#   u"n't",
#   u'you',
#   u'Google',
#   u'it',
#   u'?',
#   u'#',
#   u'weirdo',
#   u'\n'],
#  [u'What',
#   u'Google',
#   u'say',
#   u'About',
#   u'SEO',
#   u'in',
#   u'2016',
#   u'-',
#   u'WebProNews',
#   u'https://t.co/t1tdp1IPgl',
#   u'\n'],
#  [u'Gandalf',
#   u'=',
#   u'Google',
#   u'maps',
#   u'.',
#   u'Gollum',
#   u'=',
#   u'Apple',
#   u'maps',
#   u'.',
#   u'\n'],
#  [u'You',
#   u'be',
#   u'not',
#   u'go',
#   u'to',
#   u'get',
#   u'away',
#   u'with',
#   u'this',
#   u'Mr.',
#   u'Google',
#   u'Search',
#   u'\n'],
#  [u'RT',
#   u'@stephen_mcd',
#   u':',
#   u'Django',
#   u'1.9',
#   u'support',
#   u'just',
#   u'land',
#   u'in',
#   u'Mezzanine',
#   u',',
#   u'please',
#   u'help',
#   u'test',
#   u'it',
#   u':',
#   u'https://t.co/WAIshyBSdp',
#   u'#',
#   u'django',
#   u'\n'],
#  [u'try',
#   u'TunnelBear',
#   u'for',
#   u'\xa0',
#   u'Chrome',
#   u'\xa0',
#   u'to',
#   u'browse',
#   u'like',
#   u'you',
#   u'be',
#   u'in',
#   u'another',
#   u'country',
#   u':',
#   u'\xa0',
#   u'https://t.co/1x01dEAPHt',
#   u'\xa0',
#   u'@theTunnelBear',
#   u'\xa0',
#   u'https://t.co/EwVXPQZCCP',
#   u'\n'],
#  [u'2060',
#   u':',
#   u'Little',
#   u'Red',
#   u'Schoolhouse',
#   u'slates',
#   u'open',
#   u'house',
#   u',',
#   u'Jan.',
#   u'9',
#   u'-',
#   u'Wicked',
#   u'Local',
#   u'Bellingham',
#   u'https://t.co/9XGhBcO148',
#   u'\n'],
#  [u'RT',
#   u'@WearableGuru',
#   u':',
#   u'Google',
#   u'Glass',
#   u'live',
#   u'!',
#   u'see',
#   u'The',
#   u'Leaked',
#   u'Photos',
#   u'of',
#   u'The',
#   u'Next',
#   u'Version',
#   u'https://t.co/R4vNOJa1kF',
#   u'#',
#   u'WearableTech',
#   u'#',
#   u'Wearables',
#   u'https://t',
#   u'.',
#   u'\u2026',
#   u'\n'],
#  [u'"',
#   u'The',
#   u'Papi',
#   u'"',
#   u'ep',
#   u'$',
#   u'3.99',
#   u'on',
#   u'Google',
#   u'Play',
#   u'\n'],
#  [u'https://t.co/FifS8XFp4A', u'https://t.co/ht0H4VZ2jn', u'\n'],
#  [u'Whn',
#   u'ur',
#   u'fnish',
#   u'wth',
#   u'an',
#   u'essay',
#   u',',
#   u'copy',
#   u'and',
#   u'paste',
#   u'it',
#   u'into',
#   u'Google',
#   u'Translate',
#   u'and',
#   u'lsten',
#   u'to',
#   u'it',
#   u'Its',
#   u'the',
#   u'easiest',
#   u'way',
#   u'to',
#   u'find',
#   u'mistakes',
#   u'#',
#   u'ShowtimeTrabahuLa',
#   u'\n'],
#  [u'Eminem', u'-', u'Not', u'Afraid', u'https://t.co/AexXn2vafi', u'\n'],
#  [u'https://t.co/NlBOFNoUl3',
#   u'-',
#   u'Google',
#   u'Defeats',
#   u'Copyright',
#   u'Lawsuit',
#   u'Over',
#   u'Waze',
#   u'Data',
#   u'(',
#   u'Forbes',
#   u'Cross',
#   u'-',
#   u'Post',
#   u')',
#   u'\n'],
#  [u'i',
#   u'be',
#   u'try',
#   u'to',
#   u'google',
#   u'"',
#   u'oh',
#   u'yeah',
#   u'eat',
#   u'that',
#   u'bible',
#   u'"',
#   u'for',
#   u'whatever',
#   u'reason',
#   u'without',
#   u'die',
#   u'https://t.co/0pzvtMWF5M',
#   u'\n'],
#  [u'Techniques',
#   u'of',
#   u'teach',
#   u'Arabic',
#   u' ',
#   u'as',
#   u'a',
#   u'Foreign',
#   u'Language',
#   u'through',
#   u'Constructivist',
#   u'Paradigm',
#   u':',
#   u'Malaysian',
#   u'Perspective',
#   u'https://t.co/Y95mgN9JOT',
#   u'\n'],
#  [u'RT',
#   u'@LovinGianni',
#   u':',
#   u'come',
#   u'at',
#   u'me',
#   u'with',
#   u'something',
#   u'that',
#   u'be',
#   u' ',
#   u'grammatically',
#   u'incorrect',
#   u'I',
#   u'be',
#   u'fire',
#   u'yo',
#   u'ass',
#   u'up',
#   u'with',
#   u'words',
#   u'you',
#   u'go',
#   u'have',
#   u'to',
#   u'Google',
#   u'.',
#   u'\n'],
#  [u'RT', u'@GOPof_idiots', u':', u'@Libertea2012', u'\n'],
#  [u'let',
#   u'help',
#   u'Bernie',
#   u'get',
#   u'his',
#   u'message',
#   u'out',
#   u'since',
#   u'the',
#   u'media',
#   u'be',
#   u'not',
#   u'help',
#   u'him',
#   u'like',
#   u'they',
#   u'r',
#   u'Hillary',
#   u'&',
#   u'amp',
#   u';',
#   u'trump',
#   u'https',
#   u':',
#   u'\u2026',
#   u'\n'],
#  [u'I',
#   u'be',
#   u'now',
#   u'an',
#   u'E',
#   u'-',
#   u'List',
#   u'celebrity',
#   u'in',
#   u'Kim',
#   u'Kardashian',
#   u':',
#   u'Hollywood',
#   u'.',
#   u'You',
#   u'can',
#   u'be',
#   u'famous',
#   u'too',
#   u'by',
#   u'play',
#   u'on',
#   u'Android',
#   u'!',
#   u'https://t.co/N7IobTzhjh',
#   u'\n'],
#  [u'New',
#   u'Event',
#   u'Now',
#   u'On',
#   u'.',
#   u'get',
#   u'New',
#   u'Rank',
#   u'S',
#   u'Monsters',
#   u'.',
#   u'App',
#   u'Store',
#   u':',
#   u'https://t.co/MfM7E5Kn5e',
#   u'Google',
#   u'play',
#   u':',
#   u'https://t.co/hTvSZdvuuz',
#   u'#',
#   u'DarkSummoner',
#   u'\n'],
#  [u'Native',
#   u'American',
#   u'Flute',
#   u'Music',
#   u':',
#   u'Meditation',
#   u'Music',
#   u'for',
#   u'Shamanic',
#   u'Astral',
#   u'Projection',
#   u',',
#   u'Healing',
#   u'Music',
#   u'https://t.co/4kq77Fihw7',
#   u'\n'],
#  [u'RT',
#   u'@ezralevant',
#   u':',
#   u'Here',
#   u'be',
#   u'why',
#   u'I',
#   u'be',
#   u'worried',
#   u'about',
#   u'censorship',
#   u'from',
#   u'@google',
#   u',',
#   u'@twitter',
#   u'&',
#   u'amp',
#   u';',
#   u'@facebook',
#   u'in',
#   u'2016',
#   u'.',
#   u'Because',
#   u'they',
#   u'say',
#   u'they',
#   u'will',
#   u'do',
#   u'it',
#   u':',
#   u'https:/',
#   u'\u2026',
#   u'\n'],
#  [u'Course',
#   u'Materials',
#   u'for',
#   u'Statistics',
#   u'(',
#   u'The',
#   u'Easier',
#   u'Way',
#   u')',
#   u'With',
#   u'R',
#   u'https://t.co/b4UDeHX8ZE',
#   u'#',
#   u'rstats',
#   u'\n'],
#  [u'RT',
#   u'@TheMoneyGenie',
#   u':',
#   u'3',
#   u'Big',
#   u'Lessons',
#   u'from',
#   u'3',
#   u'Successful',
#   u'Entrepreneurs',
#   u' ',
#   u'work',
#   u'from',
#   u'home',
#   u'https://t.co/efgCnlgB9X',
#   u'https://t.co/ZPkeT3x8e4',
#   u'\n'],
#  [u'Google',
#   u'"',
#   u'puckle',
#   u'gun',
#   u'"',
#   u'.',
#   u'https://t.co/jQW6RkFDT7',
#   u'\n'],
#  [u'Hip',
#   u'Hop',
#   u'Alumni',
#   u'#',
#   u'HHA',
#   u'@google',
#   u'Blogger',
#   u'https://t.co/eZEMPn9xBT',
#   u'&',
#   u'amp',
#   u';',
#   u'https://t.co/Zq15au76CJ',
#   u'#',
#   u'HHA',
#   u'@YouTube',
#   u'Channel',
#   u'https://t.co/qBZDnI5TcB',
#   u'2016',
#   u'\n'],
#  [u'@rustybrick',
#   u'sir',
#   u'please',
#   u'tell',
#   u'me',
#   u'latest',
#   u'@google',
#   u'Algorithm',
#   u'in',
#   u'2016',
#   u'\n'],
#  [u'@Kappa_Kappa',
#   u'you',
#   u'have',
#   u'to',
#   u'google',
#   u'it',
#   u'for',
#   u'real',
#   u'?',
#   u'\n'],
#  [u'2057',
#   u':',
#   u'Paul',
#   u'Jacoulet',
#   u"'s",
#   u'widowed',
#   u'mother',
#   u'remarry',
#   u'and',
#   u'settle',
#   u'in',
#   u'Korea',
#   u'.',
#   u'His',
#   u'-',
#   u'Maine',
#   u'Antique',
#   u'Digest',
#   u'https://t.co/3Ed80jHX7t',
#   u'\n'],
#  [u'RT',
#   u'@abogomolov',
#   u':',
#   u'New',
#   u'in',
#   u'Symfony',
#   u'2.8',
#   u':',
#   u'DX',
#   u'Improvements',
#   u'\n'],
#  [u'\n'],
#  [u'https://t.co/jD8V92Swz2', u'#', u'symfony', u'\n'],
#  [u'@Georgina944',
#   u'go',
#   u'to',
#   u'this',
#   u'website',
#   u'.',
#   u'https://t.co/4O42egV2MV',
#   u'copy',
#   u'and',
#   u'paste',
#   u'it',
#   u'in',
#   u'twitter',
#   u'.',
#   u'Tweet',
#   u'more',
#   u'for',
#   u'#',
#   u'TeamSeventeen',
#   u'\n'],
#  [u'Phase',
#   u'One',
#   u'XF',
#   u'100MP',
#   u'use',
#   u'similar',
#   u'A7rII',
#   u'sensor',
#   u'tech',
#   u'.',
#   u'First',
#   u'short',
#   u'image',
#   u'test',
#   u'impressions',
#   u'.',
#   u'|',
#   u'\u2026',
#   u'https://t.co/sreo7UQy1m',
#   u'https://t.co/Qe2kKF44KC',
#   u'\n'],
#  [u'Morgan', u'Monday', u'\n'],
#  [u'\n'],
#  [u'Congress', u':', u'\n'],
#  [u'https://t.co/fMqqb0UjNZ', u'\n'],
#  [u'\n'],
#  [u'English', u':', u'\n'],
#  [u'https://t.co/ugQ8CeyEFT', u'\n'],
#  [u'\n'],
#  [u'German', u':', u'\n'],
#  [u'https://t.co/5ottfHrhgW', u'https://t.co/6EM90xm591', u'\n'],
#  [u'Eminem',
#   u'-',
#   u'The',
#   u'Real',
#   u'Slim',
#   u'Shady',
#   u'(',
#   u'Edited',
#   u')',
#   u'https://t.co/RJHB3ZK07s',
#   u'\n'],
#  [u'I',
#   u'have',
#   u'enter',
#   u'to',
#   u'win',
#   u'a',
#   u'Google',
#   u'Nexus',
#   u'6P',
#   u'from',
#   u'@MakeUseOf',
#   u'!',
#   u'https://t.co/y8fiCNFWHo',
#   u'#',
#   u'giveaway',
#   u'#',
#   u'competition',
#   u'\n'],
#  [u'RT',
#   u'@RealGoaIs',
#   u':',
#   u'when',
#   u'you',
#   u'google',
#   u'one',
#   u'question',
#   u'and',
#   u'find',
#   u'a',
#   u'quizlet',
#   u'for',
#   u'the',
#   u'whole',
#   u'test',
#   u'https://t.co/wKVjfkbIug',
#   u'\n'],
#  [u'RT',
#   u'@teropa',
#   u':',
#   u'Google',
#   u'analytics',
#   u'tell',
#   u'me',
#   u'the',
#   u'Full',
#   u'-',
#   u'Stack',
#   u'Redux',
#   u'Tutorial',
#   u'have',
#   u'pass',
#   u'110k',
#   u'visitors',
#   u'.',
#   u'That',
#   u'\u2019s',
#   u'crazy',
#   u'.',
#   u'\n'],
#  [u'RT',
#   u'@mikealbers23',
#   u':',
#   u'Great',
#   u'new',
#   u'workout',
#   u'app',
#   u'!',
#   u'\n'],
#  [u'https://t.co/m7H5yTCVew', u'\n'],
#  [u'\n'],
#  [u'#',
#   u'workout',
#   u'#',
#   u'fitness',
#   u'#',
#   u'gym',
#   u'#',
#   u'exercise',
#   u'#',
#   u'health',
#   u'\n'],
#  [u'#', u'DowntonAbbey', u'#', u'quickworkout', u'http', u'\u2026', u'\n'],
#  [u'@lawwrah',
#   u'@kLa_AnNe33',
#   u'@itsOTHquotes',
#   u'do',
#   u"n't",
#   u'google',
#   u'any',
#   u'of',
#   u'it',
#   u'...',
#   u'I',
#   u'always',
#   u'make',
#   u'that',
#   u'mistake',
#   u'...',
#   u'Still',
#   u'SO',
#   u'GOOD',
#   u'though',
# ...
#   u'\n'],
#  [u'#',
#   u'Google',
#   u'Helps',
#   u'Analyze',
#   u'If',
#   u'Rooftop',
#   u'Solar',
#   u'Panels',
#   u'be',
#   u'Good',
#   u'Deal',
#   u'-',
#   u'https://t.co/CUvfqQ1pf9',
#   u'https://t.co/da35f0YR02',
#   u'\n'],
#  [u'RT',
#   u'@paperphotoyo',
#   u':',
#   u'Just',
#   u'have',
#   u'to',
#   u'Google',
#   u'synonyms',
#   u'for',
#   u'the',
#   u'word',
#   u'creative',
#   u'.',
#   u'\n'],
#  [u'\n'],
#  [u'The', u'irony', u'be', u'not', u'lose', u'on', u'me', u'.', u'\n'],
#  [u'RT',
#   u'@Arzaylea',
#   u':',
#   u'@sweetIieslrh',
#   u'Google',
#   u'"',
#   u'instagram',
#   u'bio',
#   u'spaces',
#   u'"',
#   u'and',
#   u'it',
#   u'will',
#   u'let',
#   u'you',
#   u'copy',
#   u'and',
#   u'paste',
#   u'it',
#   u':)',
#   u'\n'],
#  [u'Brackets',
#   u'update',
#   u'!',
#   u'change',
#   u'sizing',
#   u'to',
#   u'make',
#   u'reading',
#   u'easier',
#   u':',
#   u'https://t.co/1W3yfwjOgI',
#   u'\n'],
#  [u'@MariahJordan9',
#   u'at',
#   u'least',
#   u'Google',
#   u'be',
#   u'try',
#   u'to',
#   u'say',
#   u'a',
#   u'life',
#   u'\n'],
#  [u'What',
#   u'self',
#   u'fix',
#   u'negativity.1',
#   u'occur',
#   u'google',
#   u'present',
#   u'-',
#   u'time',
#   u'40',
#   u'days',
#   u'-',
#   u'my',
#   u'recondite',
#   u'automation',
#   u'lickspit',
#   u':',
#   u'OpMg',
#   u'\n'],
#  [u'Google', u'Cultural', u'Institute', u'\n'],
#  [u'create',
#   u'your',
#   u'own',
#   u'galleries',
#   u'and',
#   u'share',
#   u'favourite',
#   u'find',
#   u'with',
#   u'friends',
#   u'.',
#   u'\n'],
#  [u'https://t.co/nIx9z94TPc', u'\n'],
#  [u'I',
#   u'be',
#   u'now',
#   u'a',
#   u'D',
#   u'-',
#   u'List',
#   u'celebrity',
#   u'in',
#   u'Kim',
#   u'Kardashian',
#   u':',
#   u'Hollywood',
#   u'.',
#   u'You',
#   u'can',
#   u'be',
#   u'famous',
#   u'too',
#   u'by',
#   u'play',
#   u'on',
#   u'Android',
#   u'!',
#   u'https://t.co/7p80x599JO',
#   u'\n'],
#  [u'love',
#   u'this',
#   u'!',
#   u'check',
#   u'out',
#   u'All',
#   u'for',
#   u'One',
#   u'by',
#   u'Five',
#   u'for',
#   u'fight',
#   u'-',
#   u'https://t.co/r34fG3fLCB',
#   u'\n'],
#  [u'King',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'.',
#   u'Summon',
#   u'today',
#   u'.',
#   u'App',
#   u'Store',
#   u':',
#   u'https://t.co/uCuUIGQxB1',
#   u'Google',
#   u'play',
#   u':',
#   u'https://t.co/xl4W6voTzQ',
#   u'#',
#   u'DarkSummoner',
#   u'\n'],
#  [u'@Nadimah1505',
#   u'here',
#   u'you',
#   u'go',
#   u'!',
#   u'!',
#   u'!',
#   u'https://t.co/J7Qly9Pkb1',
#   u'\n'],
#  [u'RT',
#   u'@GoogleExpertUK',
#   u':',
#   u'would',
#   u'your',
#   u'company',
#   u'benefit',
#   u'from',
#   u'a',
#   u'tailored',
#   u'#',
#   u'Google',
#   u'&',
#   u'amp',
#   u';',
#   u'#',
#   u'SocialMedia',
#   u'seminar',
#   u'?',
#   u'0161',
#   u'432',
#   u'7268',
#   u'https://t.co/rkfnLTbsMD',
#   u'https',
#   u':',
#   u'\u2026',
#   u'\n'],
#  [u'If',
#   u'interested',
#   u'in',
#   u'help',
#   u'test',
#   u'MazeVR',
#   u'for',
#   u'Google',
#   u'Cardboard',
#   u'on',
#   u'iPhone',
#   u'5',
#   u'or',
#   u'6',
#   u',',
#   u'DM',
#   u'your',
#   u'email',
#   u'address',
#   u'.',
#   u'TestFlight',
#   u'require',
#   u'it',
#   u'.',
#   u'Thanks',
#   u'.',
#   u'\n'],
#  [u'broker',
#   u'the',
#   u'premium',
#   u'domain',
#   u':',
#   u'https://t.co/lACAov189I',
#   u'interested',
#   u'?',
#   u'@AOL',
#   u'@comcast',
#   u'@google',
#   u'@yahoo',
#   u'@b',
#   u'@MSN',
#   u'@Microsoft',
#   u'ristosdomains@gmail.com',
#   u'\n'],
#  [u'RT',
#   u'@Im__Joshi',
#   u':',
#   u'@pdhana',
#   u'@BKDoss',
#   u'@psrajarajan',
#   u'@plk_raja',
#   u'google',
#   u'itself',
#   u'be',
#   u'make',
#   u'comedy',
#   u'.',
#   u'EV',
#   u'Ramasamy',
#   u'naaickar',
#   u'\U0001f61b\U0001f61c\U0001f600',
#   u'https://t.co/6MozJHn4Ef',
#   u'\n'],
#  [u'I',
#   u'like',
#   u'a',
#   u'@YouTube',
#   u'video',
#   u'https://t.co/j20RVpLTAi',
#   u'10',
#   u'Things',
#   u'You',
#   u'should',
#   u'Never',
#   u'Google',
#   u'(',
#   u'WARNING',
#   u'GROSS',
#   u')',
#   u'\n'],
#  [u'RT',
#   u'@EastRidgeIBL',
#   u':',
#   u'Week',
#   u'2',
#   u'Power',
#   u'Rankings\U0001f608',
#   u':',
#   u'https://t.co/1xfRayMvpX',
#   u'\n'],
#  [u'Sometimes',
#   u'I',
#   u'google',
#   u'cute',
#   u'ways',
#   u'to',
#   u'ask',
#   u'someone',
#   u'out',
#   u'cause',
#   u'my',
#   u'ideas',
#   u'suck',
#   u'asf',
#   u'\n'],
#  [u'SB',
#   u'Nation',
#   u':',
#   u'Colts',
#   u'vs.',
#   u'Titans',
#   u'final',
#   u'score',
#   u':',
#   u'Colts',
#   u'beat',
#   u'Titans',
#   u'30',
#   u'-',
#   u'24',
#   u'in',
#   u'what',
#   u'be',
#   u'likely',
#   u'Chuck',
#   u'Pagano',
#   u"'s",
#   u'final',
#   u'game',
#   u'.',
#   u'https://t.co/dFFsd8h1AU',
#   u'\n'],
#  [u'King',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'.',
#   u'Summon',
#   u'today',
#   u'.',
#   u'App',
#   u'Store',
#   u':',
#   u'https://t.co/8DrU0of1TZ',
#   u'Google',
#   u'play',
#   u':',
#   u'https://t.co/L1BYJ42l47',
#   u'#',
#   u'DarkSummoner',
#   u'\n'],
#  [u'RT',
#   u'@LoveLife201114',
#   u':',
#   u'#',
#   u'MakingAMurderer',
#   u'@HelpStevenAvery',
#   u'\n'],
#  [u'\n'],
#  [u'One',
#   u'can',
#   u'leave',
#   u'the',
#   u'sherifs',
#   u'office',
#   u'comments',
#   u'via',
#   u'Google',
#   u'maps',
#   u'.',
#   u'https://t.co/QDonXt485g',
#   u'\n'],
#  [u'I',
#   u'be',
#   u'not',
#   u'sure',
#   u'what',
#   u'you',
#   u'mean',
#   u'.',
#   u'What',
#   u'sort',
#   u'of',
#   u'questions',
#   u'?',
#   u'I',
#   u'like',
#   u'Stikman',
#   u'.',
#   u'Google',
#   u'him',
#   u'.',
#   u'If',
#   u'you',
#   u'have',
#   u'questions',
#   u'know',
#   u'a',
#   u'ton',
#   u'.',
#   u'\n'],
#  [u'#', u'Google', u'answer', u'your', u'questions', u'.', u'\n'],
#  [u'#',
#   u'LarryPage',
#   u'answer',
#   u'the',
#   u'fundamental',
#   u'question',
#   u'.',
#   u'\n'],
#  [u'#',
#   u'MondayMotivation',
#   u'#',
#   u'Quote',
#   u'https://t.co/oHHehg9e4s',
#   u'\n'],
#  [u'Agoa',
#   u'trade',
#   u'stand',
#   u'-',
#   u'off',
#   u':',
#   u'Ties',
#   u'between',
#   u'SA',
#   u',',
#   u'US',
#   u'in',
#   u'jeopardy',
#   u'|',
#   u'eNCA',
#   u'https://t.co/RwWHQfJkwv',
#   u'\n'],
#  [u'New',
#   u'Event',
#   u'Now',
#   u'On',
#   u'.',
#   u'get',
#   u'New',
#   u'Rank',
#   u'S',
#   u'Monsters',
#   u'.',
#   u'App',
#   u'Store',
#   u':',
#   u'https://t.co/kYjKZwsZjl',
#   u'Google',
#   u'play',
#   u':',
#   u'https://t.co/Gzx32HHMWU',
#   u'#',
#   u'DarkSummoner',
#   u'\n'],
#  [u'@jasondemanzo',
#   u'it',
#   u'will',
#   u'give',
#   u'you',
#   u'something',
#   u'to',
#   u'google',
#   u'since',
#   u'you',
#   u'think',
#   u'you',
#   u'know',
#   u'so',
#   u'much',
#   u'\n'],
#  [u'*',
#   u'try',
#   u'to',
#   u'find',
#   u'bootleg',
#   u'version',
#   u'of',
#   u'TFA',
#   u'on',
#   u'google',
#   u'*',
#   u'\n'],
#  [u'The',
#   u'best',
#   u'advice',
#   u'I',
#   u'have',
#   u'ever',
#   u'receive',
#   u'from',
#   u'Google',
#   u'-',
#   u'how',
#   u'to',
#   u'numb',
#   u'emotional',
#   u'pain',
#   u'https://t.co/bjD8pJ5Zyw',
#   u'\n'],
#  [u'Thanks',
#   u'for',
#   u'follow',
#   u'@egibis_blog',
#   u'!',
#   u'look',
#   u'for',
#   u'me',
#   u'on',
#   u'FB',
#   u',',
#   u'Google+',
#   u',',
#   u'LinkedIn',
#   u'&',
#   u'amp',
#   u';',
#   u'Pinterest',
#   u'under',
#   u'truCrowd',
#   u'!',
#   u'see',
#   u'ya',
#   u'there',
#   u'!',
#   u'\n'],
#  [u'ECO',
#   u'302',
#   u'WEEK',
#   u'3',
#   u'QUIZ',
#   u'STRAYER-',
#   u'https://t.co/BURTA5bO3w',
#   u'\n'],
#  [u'7',
#   u'"',
#   u'A33',
#   u'Google',
#   u'Android',
#   u'4.4',
#   u'Quad',
#   u'Core',
#   u'Dual',
#   u'Camera',
#   u'8',
#   u'GB',
#   u'Tablet',
#   u'PC',
#   u'WiFi',
#   u'Bluetooth',
#   u'-',
#   u'Bid',
#   u'Now',
#   u'!',
#   u'On',
#   u'\u2026',
#   u'https://t.co/OEtVgkSzm3',
#   u'https://t.co/RJbkScWj2Y',
#   u'\n'],
#  [u'#',
#   u'Google',
#   u'to',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'a',
#   u'good',
#   u'deal',
#   u'https://t.co/rRMKYYufE6',
#   u'\n'],
#  [u'#',
#   u'Google',
#   u'to',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'a',
#   u'good',
#   u'deal',
#   u'https://t.co/5DFsj2V9Zf',
#   u'\n'],
#  [u'@wisdom_stars',
#   u'Summary',
#   u'of',
#   u'"',
#   u'The',
#   u'Rise',
#   u'of',
#   u'Hate',
#   u'Search',
#   u'.',
#   u'"',
#   u'#',
#   u'wisdomstarsnews',
#   u'#',
#   u'hatecrimes',
#   u'#',
#   u'Google',
#   u'#',
#   u'terrorism',
#   u'#',
#   u'ParisAttacks',
#   u'https://t.co/f4pBPh1b7F',
#   u'\n'],
#  [u'Reliable',
#   u'Seattle',
#   u'town',
#   u'car',
#   u'hire',
#   u'services',
#   u'.For',
#   u'more',
#   u'information',
#   u'click',
#   u'on',
#   u'this',
#   u'link',
#   u'https://t.co/Kuq5UnwWGq',
#   u'.',
#   u'\n'],
#  [u'King',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'.',
#   u'Summon',
#   u'today',
#   u'.',
#   u'App',
#   u'Store',
#   u':',
#   u'https://t.co/hN48FAuPZD',
#   u'Google',
#   u'play',
#   u':',
#   u'https://t.co/gf34ZsWpm9',
#   u'#',
#   u'DarkSummoner',
#   u'\n'],
#  [u'listen',
#   u'to',
#   u'Something',
#   u'You',
#   u'Forgot',
#   u'(',
#   u'Carter',
#   u'3',
#   u')',
#   u'by',
#   u'Lil',
#   u"'",
#   u'Wanye',
#   u'|',
#   u'https://t.co/Nu3vQf8Pfh',
#   u'\n'],
#  [u'RT',
#   u'@Dave_RI',
#   u':',
#   u'Top',
#   u'10',
#   u'Google',
#   u'Docs',
#   u'Posts',
#   u'of',
#   u'2015',
#   u'https://t.co/L6SPrPFTjT',
#   u'via',
#   u'@alicekeeler',
#   u'#',
#   u'edtech',
#   u'\n'],
#  [u'@poptivist',
#   u'@buttercupcas',
#   u'HERE',
#   u'YOU',
#   u'go',
#   u'I',
#   u'hope',
#   u'IT',
#   u'WORKS',
#   u'https://t.co/2LC6SkY1WQ',
#   u'\n'],
#  [u'gOOgle', u' ', u'https://t.co/scc7Pt3KNZ', u'\n'],
#  [u'The',
#   u'Associated',
#   u'Press',
#   u':',
#   u'Steelers',
#   u'sneak',
#   u'into',
#   u'AFC',
#   u'playoffs',
#   u'with',
#   u'28',
#   u'-',
#   u'12',
#   u'win',
#   u'over',
#   u'Browns',
#   u'.',
#   u'https://t.co/3zZGgjyp9e',
#   u'\n'],
#  [u'RT',
#   u'@GoogleExpertUK',
#   u':',
#   u'would',
#   u'your',
#   u'company',
#   u'benefit',
#   u'from',
#   u'a',
#   u'tailored',
#   u'#',
#   u'Google',
#   u'&',
#   u'amp',
#   u';',
#   u'#',
#   u'SocialMedia',
#   u'seminar',
#   u'?',
#   u'0161',
#   u'432',
#   u'7268',
#   u'https://t.co/rkfnLTbsMD',
#   u'https',
#   u':',
#   u'\u2026',
#   u'\n'],
#  [u'https://t.co/sy3DaQnYBt',
#   u'\u2014',
#   u'i',
#   u'just',
#   u'see',
#   u'this',
#   u'..',
#   u'thank',
#   u'you',
#   u'for',
#   u'share',
#   u'it',
#   u':)',
#   u'https://t.co/FkL5CKChbv',
#   u'\n'],
#  [u'Waka',
#   u'Flocka',
#   u'&',
#   u'amp',
#   u';',
#   u'Young',
#   u'Sizzle',
#   u'-',
#   u'New',
#   u'Year',
#   u'(',
#   u'Prod',
#   u'.',
#   u'By',
#   u'Luke',
#   u')',
#   u'https://t.co/SeK0tlclgh',
#   u'\n'],
#  [u'@JeremyLawrencee',
#   u'ya',
#   u'FIOS',
#   u'here',
#   u'at',
#   u'my',
#   u'place',
#   u'and',
#   u'at',
#   u'my',
#   u'parents',
#   u'.',
#   u'Hopefully',
#   u'we',
#   u'get',
#   u'Google',
#   u'fiber',
#   u'here',
#   u'\n'],
#  [u'spyhuman',
#   u'be',
#   u'mobile',
#   u'track',
#   u'application',
#   u'gps',
#   u' ',
#   u'call',
#   u'logs',
#   u',',
#   u'call',
#   u'recording',
#   u'\n'],
#  [u'https://t.co/x8TRf1SU0O', u'\n'],
#  [u'So',
#   u'thankful',
#   u'for',
#   u'the',
#   u'Google',
#   u'Chromecast',
#   u'let',
#   u'me',
#   u'stream',
#   u'music',
#   u'from',
#   u'my',
#   u'phone',
#   u'to',
#   u'my',
#   u'tv\U0001f64f\U0001f64f\U0001f64f\U0001f64f',
#   u'\n'],
#  [u'RT',
#   u'@GoogleExpertUK',
#   u':',
#   u'#',
#   u'Google',
#   u'support',
#   u'Swedish',
#   u'Chef',
#   u'from',
#   u'The',
#   u'Muppets',
#   u'!',
#   u'@MuppetsStudio',
#   u'#',
#   u'internet',
#   u'#',
#   u'technology',
#   u'https://t.co/YjupLi6aMA',
#   u'\n'],
#  [u'RT',
#   u'@LovinGianni',
#   u':',
#   u'come',
#   u'at',
#   u'me',
#   u'with',
#   u'something',
#   u'that',
#   u'be',
#   u' ',
#   u'grammatically',
#   u'incorrect',
#   u'I',
#   u'be',
#   u'fire',
#   u'yo',
#   u'ass',
#   u'up',
#   u'with',
#   u'words',
#   u'you',
#   u'go',
#   u'have',
#   u'to',
#   u'Google',
#   u'.',
#   u'\n'],
#  [u'How',
#   u'to',
#   u'use',
#   u'Google',
#   u'effectively',
#   u'https://t.co/7FQkrN0RPs',
#   u'\n'],
#  [u'RT',
#   u'@wmsolomon',
#   u':',
#   u'do',
#   u"n't",
#   u'use',
#   u'google',
#   u'for',
#   u'your',
#   u'research',
#   u'just',
#   u'read',
#   u'history',
#   u',',
#   u'it',
#   u'be',
#   u'fun',
#   u',',
#   u'educate',
#   u'&',
#   u'amp',
#   u';',
#   u'relevant',
#   u'.',
#   u'In',
#   u'a',
#   u'funny',
#   u'way',
#   u',',
#   u'History',
#   u'keep',
#   u'repeatin',
#   u'\u2026',
#   u'\n'],
#  [u'#',
#   u'SocialMediaTips',
#   u':',
#   u'Powerful',
#   u'Personal',
#   u'Branding',
#   u'Tips',
#   u'to',
#   u'take',
#   u'You',
#   u'from',
#   u'Digital',
#   u'Zero',
#   u'...',
#   u'https://t.co/27uxxLf019',
#   u'+',
#   u'SMM\u21achttps://t.co/2dOA1wsCRU',
#   u'\n'],
#  [u'#',
#   u'SocialMediaTips',
#   u':',
#   u'Powerful',
#   u'Personal',
#   u'Branding',
#   u'Tips',
#   u'to',
#   u'take',
#   u'You',
#   u'from',
#   u'Digital',
#   u'Zero',
#   u'...',
#   u'https://t.co/UW7BkPII71',
#   u'+',
#   u'SMM\u21achttps://t.co',
#   u'/',
#   u'VneDwWKkhb',
#   u'\n'],
#  [u'Sometimes',
#   u'I',
#   u'call',
#   u'303',
#   u'-',
#   u'499',
#   u'-',
#   u'7111',
#   u'and',
#   u'listen',
#   u'to',
#   u'the',
#   u'atomic',
#   u'clock',
#   u'at',
#   u'NIST',
#   u'tick',
#   u'off',
#   u'seconds',
#   u'.',
#   u'"',
#   u'At',
#   u'the',
#   u'tone',
#   u',',
#   u'5:44',
#   u'UTC',
#   u'"',
#   u'https://t.co/W2id51EpX2',
#   u'\n'],
#  [u'Microsoft',
#   u'will',
#   u'inform',
#   u'You',
#   u'If',
#   u'Government',
#   u'be',
#   u'spy',
#   u'on',
#   u'You',
#   u'https://t.co/1uPEDcWKE8',
#   u'\n'],
#  [u'@MEsipisu',
#   u'NEW',
#   u'VIDEO',
#   u'ALERT',
#   u'!',
#   u'!',
#   u'https://t.co/NTs3QM5YU5',
#   u'\n'],
#  [u'RT',
#   u'@SurajRaviFan',
#   u':',
#   u'#',
#   u'MIRUTHANtrailer',
#   u'rock',
#   u'@Youtube',
#   u'with',
#   u'6',
#   u'Lakhs+',
#   u'Views',
#   u'&',
#   u'amp',
#   u';',
#   u'8K+',
#   u'Likes',
#   u'@actor_jayamravi',
#   u'@shaktirajan',
#   u'#',
#   u'TheriHIT',
#   u'https://t.co/7T',
#   u'\u2026',
#   u'\n'],
#  [u'King',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'.',
#   u'Summon',
#   u'today',
#   u'.',
#   u'App',
#   u'Store',
#   u':',
#   u'https://t.co/17X4BV1hbG',
#   u'Google',
#   u'play',
#   u':',
#   u'https://t.co/qynhV3c83a',
#   u'#',
#   u'DarkSummoner',
#   u'\n'],
#  [u'Zaker',
#   u'Pro',
#   u':',
#   u'Azkar',
#   u'Muslim',
#   u'pray',
#   u'-',
#   u'Android',
#   u'Apps',
#   u'on',
#   u'Google',
#   u'Play',
#   u'https://t.co/fvwHOsVdcC',
#   u'\n'],
#  [u'write',
#   u'an',
#   u'Android',
#   u'application',
#   u' ',
#   u'by',
#   u'patilvaibhavp99',
#   u'https://t.co/klyemTUGzL',
#   u'I',
#   u'want',
#   u'to',
#   u'integrate',
#   u'google',
#   u'auto',
#   u'complete',
#   u'place',
#   u' ',
#   u'API',
#   u'in',
#   u'android',
#   u'ap',
#   u'\u2026',
#   u'\n'],
#  [u'.@sardesairajdeep',
#   u'It',
#   u'take',
#   u'58',
#   u'minutes',
#   u'now',
#   u'as',
#   u'per',
#   u'Google',
#   u'maps',
#   u'...',
#   u'unless',
#   u'of',
#   u'course',
#   u'Google',
#   u'be',
#   u'a',
#   u'Modi',
#   u'agent',
#   u'.',
#   u'https://t.co/flMt7tFYwu',
#   u'\n'],
#  [u'UNIVERSO',
#   u'NOKIA',
#   u':',
#   u'NewsSpot',
#   u'!',
#   u'Google',
#   u'reader',
#   u'potente',
#   u'e',
#   u'versatile',
#   u'!',
#   u'https://t.co/0kaUc01saT',
#   u'\n'],
#  [u'RT',
#   u'@koderedapps',
#   u':',
#   u'check',
#   u'out',
#   u'our',
#   u'#',
#   u'new',
#   u'#',
#   u'android',
#   u'#',
#   u'game',
#   u'#',
#   u'RoadRage',
#   u'https://t.co/38bQtBEYOm',
#   u'#',
#   u'endless',
#   u'#',
#   u'free',
#   u'#',
#   u'addictive',
#   u'#',
#   u'shooter',
#   u'#',
#   u'racing',
#   u'#',
#   u'rockets',
#   u'#',
#   u'b',
#   u'\u2026',
#   u'\n'],
#  [u'RT',
#   u'@bella230893',
#   u':',
#   u'[',
#   u'Preview',
#   u']',
#   u'BestPlan',
#   u'!',
#   u'Calendar',
#   u'by',
#   u'@PlanBAP',
#   u'\n'],
#  [u'To',
#   u'order',
#   u'please',
#   u'refer',
#   u'here',
#   u'\U0001f447\U0001f3fb(Malaysia',
#   u'go',
#   u')',
#   u'https://t.co/UWzYuNmwHV',
#   u'https://t.co/',
#   u'\u2026',
#   u'\n'],
#  [u'1451886241-Weekly',
#   u'European',
#   u'Tour',
#   u'Fantasy',
#   u'Golf',
#   u'App',
#   u'for',
#   u'Android',
#   u'https://t.co/4hsePaDOwT',
#   u'\n'],
#  [u'The',
#   u'Associated',
#   u'Press',
#   u':',
#   u'Vikings',
#   u'take',
#   u'NFC',
#   u'North',
#   u',',
#   u'hold',
#   u'on',
#   u'to',
#   u'beat',
#   u'Packers',
#   u'20',
#   u'-',
#   u'13',
#   u'.',
#   u'https://t.co/3c9NfB3Kxg',
#   u'\n'],
#  [u'King',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'.',
#   u'Summon',
#   u'today',
#   u'.',
#   u'App',
#   u'Store',
#   u':',
#   u'https://t.co/S4is1P6krB',
#   u'Google',
#   u'play',
#   u':',
#   u'https://t.co/fQvCcpLWXl',
#   u'#',
#   u'DarkSummoner',
#   u'\n'],
#  [u'New',
#   u'Event',
#   u'Now',
#   u'On',
#   u'.',
#   u'get',
#   u'New',
#   u'Rank',
#   u'S',
#   u'Monsters',
#   u'.',
#   u'App',
#   u'Store',
#   u':',
#   u'https://t.co/CO72KI2eA5',
#   u'Google',
#   u'play',
#   u':',
#   u'https://t.co/X3b0CL0DDD',
#   u'#',
#   u'DarkSummoner',
#   u'\n'],
#  [u'@EmmaaJoyce',
#   u'@chichenry',
#   u'I',
#   u'look',
#   u'it',
#   u'up',
#   u'on',
#   u'google',
#   u'and',
#   u'it',
#   u'give',
#   u'me',
#   u'nothing',
#   u'\n'],
#  [u'I',
#   u'just',
#   u'receive',
#   u'a',
#   u'reward',
#   u':',
#   u'Legendary',
#   u'Island',
#   u'!',
#   u'https://t.co/UzAqFNNif0',
#   u'#',
#   u'Android',
#   u'#',
#   u'Gameinsight',
#   u'#',
#   u'Androidgames',
#   u'\n'],
#  [u'New',
#   u'Event',
#   u'Now',
#   u'On',
#   u'.',
#   u'get',
#   u'New',
#   u'Rank',
#   u'S',
#   u'Monsters',
#   u'.',
#   u'App',
#   u'Store',
#   u':',
#   u'https://t.co/s9dkLyvOvA',
#   u'Google',
#   u'play',
#   u':',
#   u'https://t.co/nmwqU8hDkX',
#   u'#',
#   u'DarkSummoner',
#   u'\n'],
#  ...]

# %% [markdown]
# ### Exercise 2b:
# Build a `word2vec` model.
# Test the window size as well - this is how many surrounding words need to be used to model a word. What do you think is appropriate for Twitter?

# %%
model = Word2Vec(text_split, size=100, window=4, min_count=5, workers=4)
print model
# Out:
# Word2Vec(vocab=1732, size=100, alpha=0.025)

# %% [markdown]
# ### Exercise 2c:
# Test your word2vec model with a few similarity functions.
# * Find words similar to 'Syria'.
# * Find words similar to 'war'.
# * Find words similar to "Iran".
# * Find words similar to 'Verizon'.

# %%
model.most_similar(positive=['Syria'])
# Out:
# [(u'opposition', 0.9990753531455994),
#  (u'Russia', 0.9984109401702881),
#  (u'Bing', 0.9968112707138062),
#  (u'life', 0.9961879253387451),
#  (u'death', 0.9961668848991394),
#  (u'art', 0.996021568775177),
#  (u'benefit', 0.9959487318992615),
#  (u'Ads', 0.9959076642990112),
#  (u'Results', 0.9954224228858948),
#  (u'Syrians', 0.9953066110610962)]

# %% [markdown]
# # Exercise 2d
#
# Adjust the choices / parameters in (b) and (c) as necessary.

# %% [markdown]
# ## Exercise 3
#
# Filter tweets to those that mention 'Iran' or similar entities and 'war' or similar entities.
# * Do this using just spacy.
# * Do this using word2vec similarity scores.

# %%
# Using spacy
for tweet in tweets:
    parsed = nlp_toolkit(tweet)
    pass

# %%
# Using word2vec similarity scores
for tweet in tweets[:200]:
    parsed = nlp_toolkit(tweet)
    pass
